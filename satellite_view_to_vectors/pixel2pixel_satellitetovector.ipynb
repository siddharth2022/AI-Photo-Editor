# %%
# !wget "http://efrosgans.eecs.berkeley.edu/pix2pix/datasets/maps.tar.gz"
# Out:
# --2019-08-12 17:40:30--  http://efrosgans.eecs.berkeley.edu/pix2pix/datasets/maps.tar.gz
# Resolving efrosgans.eecs.berkeley.edu (efrosgans.eecs.berkeley.edu)... 128.32.189.73
# Connecting to efrosgans.eecs.berkeley.edu (efrosgans.eecs.berkeley.edu)|128.32.189.73|:80... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 250242400 (239M) [application/x-gzip]
# Saving to: ‘maps.tar.gz’
#
# maps.tar.gz         100%[===================>] 238.65M   581KB/s    in 3m 4s
#
# 2019-08-12 17:43:34 (1.30 MB/s) - ‘maps.tar.gz’ saved [250242400/250242400]

# %%
# !tar xvzf maps.tar.gz
# Out:
# maps/
# maps/train/
# maps/train/1.jpg
# maps/train/10.jpg
# maps/train/100.jpg
# maps/train/1000.jpg
# maps/train/1001.jpg
# maps/train/1002.jpg
# maps/train/1003.jpg
# maps/train/1004.jpg
# maps/train/1005.jpg
# maps/train/1006.jpg
# maps/train/1007.jpg
# maps/train/1008.jpg
# maps/train/1009.jpg
# maps/train/101.jpg
# maps/train/1010.jpg
# maps/train/1011.jpg
# maps/train/1012.jpg
# maps/train/1013.jpg
# maps/train/1014.jpg
# maps/train/1015.jpg
# maps/train/530.jpg
# maps/train/531.jpg
# maps/train/532.jpg
# maps/train/533.jpg
# maps/train/534.jpg
# maps/train/535.jpg
# maps/train/536.jpg
# maps/train/537.jpg
# maps/train/538.jpg
# maps/train/539.jpg
# maps/train/54.jpg
# maps/train/540.jpg
# maps/train/541.jpg
# maps/train/542.jpg
# maps/train/543.jpg
# maps/train/544.jpg
# maps/train/545.jpg
# maps/train/546.jpg
# maps/train/547.jpg
# maps/train/548.jpg
# maps/train/549.jpg
# maps/train/55.jpg
# maps/train/550.jpg
# maps/train/551.jpg
# maps/train/552.jpg
# maps/train/553.jpg
# maps/train/554.jpg
# maps/train/555.jpg
# maps/train/556.jpg
# maps/train/557.jpg
# maps/train/558.jpg
# maps/train/559.jpg
# maps/train/56.jpg
# maps/train/560.jpg
# maps/train/561.jpg
# maps/train/757.jpg
# maps/train/758.jpg
# maps/train/759.jpg
# maps/train/76.jpg
# maps/train/760.jpg
# maps/train/761.jpg
# maps/train/762.jpg
# maps/train/763.jpg
# maps/train/764.jpg
# maps/train/765.jpg
# maps/train/766.jpg
# maps/train/767.jpg
# maps/train/768.jpg
# maps/train/769.jpg
# maps/train/77.jpg
# maps/train/770.jpg
# maps/train/771.jpg
# maps/train/772.jpg
# maps/train/773.jpg
# maps/train/774.jpg
# maps/train/775.jpg
# maps/train/776.jpg
# maps/train/777.jpg
# maps/train/778.jpg
# maps/train/779.jpg
# maps/train/340.jpg
# maps/train/341.jpg
# maps/train/342.jpg
# maps/train/343.jpg
# maps/train/344.jpg
# maps/train/345.jpg
# maps/train/346.jpg
# maps/train/347.jpg
# maps/train/348.jpg
# maps/train/349.jpg
# maps/train/35.jpg
# maps/train/350.jpg
# maps/train/351.jpg
# maps/train/352.jpg
# maps/train/353.jpg
# maps/train/354.jpg
# maps/train/355.jpg
# maps/train/356.jpg
# maps/train/357.jpg
# maps/train/358.jpg
# maps/train/359.jpg
# maps/train/36.jpg
# maps/train/360.jpg
# maps/train/361.jpg
# maps/train/362.jpg
# maps/train/363.jpg
# maps/train/364.jpg
# maps/train/365.jpg
# maps/train/366.jpg
# maps/train/367.jpg
# maps/train/368.jpg
# maps/train/369.jpg
# maps/train/37.jpg
# maps/train/370.jpg
# maps/train/371.jpg
# maps/train/372.jpg
# maps/train/373.jpg
# maps/train/374.jpg
# maps/train/375.jpg
# maps/train/376.jpg
# maps/train/377.jpg
# maps/train/202.jpg
# maps/train/203.jpg
# maps/train/204.jpg
# maps/train/205.jpg
# maps/train/206.jpg
# maps/train/207.jpg
# maps/train/208.jpg
# maps/train/209.jpg
# maps/train/21.jpg
# maps/train/210.jpg
# maps/train/211.jpg
# maps/train/212.jpg
# maps/train/213.jpg
# maps/train/214.jpg
# maps/train/215.jpg
# maps/train/216.jpg
# maps/train/217.jpg
# maps/train/218.jpg
# maps/train/219.jpg
# maps/train/22.jpg
# maps/train/220.jpg
# maps/train/221.jpg
# maps/train/222.jpg
# maps/train/223.jpg
# maps/train/224.jpg
# maps/train/225.jpg
# maps/train/226.jpg
# maps/train/227.jpg
# maps/train/228.jpg
# maps/train/229.jpg
# maps/train/23.jpg
# maps/train/230.jpg
# maps/train/231.jpg
# maps/train/232.jpg
# maps/train/233.jpg
# maps/train/234.jpg
# maps/train/235.jpg
# maps/train/236.jpg
# maps/train/237.jpg
# maps/train/1016.jpg
# maps/train/1035.jpg
# maps/train/106.jpg
# maps/train/1080.jpg
# maps/train/118.jpg
# maps/train/141.jpg
# maps/train/172.jpg
# maps/train/201.jpg
# maps/train/238.jpg
# maps/train/271.jpg
# maps/train/30.jpg
# maps/train/320.jpg
# maps/train/34.jpg
# maps/train/378.jpg
# maps/train/397.jpg
# maps/train/42.jpg
# maps/train/454.jpg
# maps/train/489.jpg
# maps/train/509.jpg
# maps/train/53.jpg
# maps/train/562.jpg
# maps/train/59.jpg
# maps/train/619.jpg
# maps/train/648.jpg
# maps/train/681.jpg
# maps/train/712.jpg
# maps/train/734.jpg
# maps/train/756.jpg
# maps/train/78.jpg
# maps/train/80.jpg
# maps/train/820.jpg
# maps/train/843.jpg
# maps/train/877.jpg
# maps/train/910.jpg
# maps/train/932.jpg
# maps/train/953.jpg
# maps/train/979.jpg
# maps/train/911.jpg
# maps/train/912.jpg
# maps/train/913.jpg
# maps/train/914.jpg
# maps/train/915.jpg
# maps/train/916.jpg
# maps/train/917.jpg
# maps/train/918.jpg
# maps/train/919.jpg
# maps/train/92.jpg
# maps/train/920.jpg
# maps/train/921.jpg
# maps/train/922.jpg
# maps/train/923.jpg
# maps/train/924.jpg
# maps/train/925.jpg
# maps/train/926.jpg
# maps/train/927.jpg
# maps/train/928.jpg
# maps/train/929.jpg
# maps/train/93.jpg
# maps/train/930.jpg
# maps/train/931.jpg
# maps/train/649.jpg
# maps/train/65.jpg
# maps/train/650.jpg
# maps/train/651.jpg
# maps/train/652.jpg
# maps/train/653.jpg
# maps/train/654.jpg
# maps/train/655.jpg
# maps/train/656.jpg
# maps/train/657.jpg
# maps/train/658.jpg
# maps/train/659.jpg
# maps/train/66.jpg
# maps/train/660.jpg
# maps/train/661.jpg
# maps/train/662.jpg
# maps/train/663.jpg
# maps/train/664.jpg
# maps/train/665.jpg
# maps/train/666.jpg
# maps/train/667.jpg
# maps/train/668.jpg
# maps/train/669.jpg
# maps/train/67.jpg
# maps/train/670.jpg
# maps/train/671.jpg
# maps/train/672.jpg
# maps/train/673.jpg
# maps/train/674.jpg
# maps/train/675.jpg
# maps/train/676.jpg
# maps/train/677.jpg
# maps/train/678.jpg
# maps/train/679.jpg
# maps/train/68.jpg
# maps/train/680.jpg
# maps/train/420.jpg
# maps/train/421.jpg
# maps/train/422.jpg
# maps/train/423.jpg
# maps/train/424.jpg
# maps/train/425.jpg
# maps/train/426.jpg
# maps/train/427.jpg
# maps/train/428.jpg
# maps/train/429.jpg
# maps/train/43.jpg
# maps/train/430.jpg
# maps/train/431.jpg
# maps/train/432.jpg
# maps/train/433.jpg
# maps/train/434.jpg
# maps/train/435.jpg
# maps/train/436.jpg
# maps/train/437.jpg
# maps/train/438.jpg
# maps/train/439.jpg
# maps/train/44.jpg
# maps/train/440.jpg
# maps/train/441.jpg
# maps/train/442.jpg
# maps/train/443.jpg
# maps/train/444.jpg
# maps/train/445.jpg
# maps/train/446.jpg
# maps/train/447.jpg
# maps/train/448.jpg
# maps/train/449.jpg
# maps/train/45.jpg
# maps/train/450.jpg
# maps/train/451.jpg
# maps/train/452.jpg
# maps/train/453.jpg
# maps/train/844.jpg
# maps/train/845.jpg
# maps/train/846.jpg
# maps/train/847.jpg
# maps/train/848.jpg
# maps/train/849.jpg
# maps/train/85.jpg
# maps/train/850.jpg
# maps/train/851.jpg
# maps/train/852.jpg
# maps/train/853.jpg
# maps/train/854.jpg
# maps/train/855.jpg
# maps/train/856.jpg
# maps/train/857.jpg
# maps/train/858.jpg
# maps/train/859.jpg
# maps/train/86.jpg
# maps/train/860.jpg
# maps/train/861.jpg
# maps/train/862.jpg
# maps/train/863.jpg
# maps/train/864.jpg
# maps/train/865.jpg
# maps/train/866.jpg
# maps/train/867.jpg
# maps/train/868.jpg
# maps/train/869.jpg
# maps/train/87.jpg
# maps/train/870.jpg
# maps/train/871.jpg
# maps/train/872.jpg
# maps/train/873.jpg
# maps/train/874.jpg
# maps/train/875.jpg
# maps/train/876.jpg
# maps/train/1081.jpg
# maps/train/1082.jpg
# maps/train/1083.jpg
# maps/train/1084.jpg
# maps/train/1085.jpg
# maps/train/1086.jpg
# maps/train/1087.jpg
# maps/train/1088.jpg
# maps/train/1089.jpg
# maps/train/109.jpg
# maps/train/1090.jpg
# maps/train/1091.jpg
# maps/train/1092.jpg
# maps/train/1093.jpg
# maps/train/1094.jpg
# maps/train/1095.jpg
# maps/train/1096.jpg
# maps/train/11.jpg
# maps/train/110.jpg
# maps/train/111.jpg
# maps/train/112.jpg
# maps/train/113.jpg
# maps/train/114.jpg
# maps/train/115.jpg
# maps/train/116.jpg
# maps/train/117.jpg
# maps/train/272.jpg
# maps/train/273.jpg
# maps/train/274.jpg
# maps/train/275.jpg
# maps/train/276.jpg
# maps/train/277.jpg
# maps/train/278.jpg
# maps/train/279.jpg
# maps/train/28.jpg
# maps/train/280.jpg
# maps/train/281.jpg
# maps/train/282.jpg
# maps/train/283.jpg
# maps/train/284.jpg
# maps/train/285.jpg
# maps/train/286.jpg
# maps/train/287.jpg
# maps/train/288.jpg
# maps/train/289.jpg
# maps/train/29.jpg
# maps/train/290.jpg
# maps/train/291.jpg
# maps/train/292.jpg
# maps/train/293.jpg
# maps/train/294.jpg
# maps/train/295.jpg
# maps/train/296.jpg
# maps/train/297.jpg
# maps/train/298.jpg
# maps/train/299.jpg
# maps/train/3.jpg
# maps/train/713.jpg
# maps/train/714.jpg
# maps/train/715.jpg
# maps/train/716.jpg
# maps/train/717.jpg
# maps/train/718.jpg
# maps/train/719.jpg
# maps/train/72.jpg
# maps/train/720.jpg
# maps/train/721.jpg
# maps/train/722.jpg
# maps/train/723.jpg
# maps/train/724.jpg
# maps/train/725.jpg
# maps/train/726.jpg
# maps/train/727.jpg
# maps/train/728.jpg
# maps/train/729.jpg
# maps/train/73.jpg
# maps/train/730.jpg
# maps/train/731.jpg
# maps/train/732.jpg
# maps/train/733.jpg
# maps/train/590.jpg
# maps/train/591.jpg
# maps/train/592.jpg
# maps/train/593.jpg
# maps/train/594.jpg
# maps/train/595.jpg
# maps/train/596.jpg
# maps/train/597.jpg
# maps/train/598.jpg
# maps/train/599.jpg
# maps/train/6.jpg
# maps/train/60.jpg
# maps/train/600.jpg
# maps/train/601.jpg
# maps/train/602.jpg
# maps/train/603.jpg
# maps/train/604.jpg
# maps/train/605.jpg
# maps/train/606.jpg
# maps/train/607.jpg
# maps/train/608.jpg
# maps/train/609.jpg
# maps/train/61.jpg
# maps/train/610.jpg
# maps/train/611.jpg
# maps/train/612.jpg
# maps/train/613.jpg
# maps/train/614.jpg
# maps/train/615.jpg
# maps/train/616.jpg
# maps/train/617.jpg
# maps/train/618.jpg
# maps/train/49.jpg
# maps/train/490.jpg
# maps/train/491.jpg
# maps/train/492.jpg
# maps/train/493.jpg
# maps/train/494.jpg
# maps/train/495.jpg
# maps/train/496.jpg
# maps/train/497.jpg
# maps/train/498.jpg
# maps/train/499.jpg
# maps/train/5.jpg
# maps/train/50.jpg
# maps/train/500.jpg
# maps/train/501.jpg
# maps/train/502.jpg
# maps/train/503.jpg
# maps/train/504.jpg
# maps/train/505.jpg
# maps/train/506.jpg
# maps/train/507.jpg
# maps/train/508.jpg
# maps/train/142.jpg
# maps/train/143.jpg
# maps/train/144.jpg
# maps/train/145.jpg
# maps/train/146.jpg
# maps/train/147.jpg
# maps/train/148.jpg
# maps/train/149.jpg
# maps/train/15.jpg
# maps/train/150.jpg
# maps/train/151.jpg
# maps/train/152.jpg
# maps/train/153.jpg
# maps/train/154.jpg
# maps/train/155.jpg
# maps/train/156.jpg
# maps/train/157.jpg
# maps/train/158.jpg
# maps/train/159.jpg
# maps/train/16.jpg
# maps/train/160.jpg
# maps/train/161.jpg
# maps/train/162.jpg
# maps/train/163.jpg
# maps/train/164.jpg
# maps/train/165.jpg
# maps/train/166.jpg
# maps/train/167.jpg
# maps/train/168.jpg
# maps/train/169.jpg
# maps/train/17.jpg
# maps/train/170.jpg
# maps/train/171.jpg
# maps/train/954.jpg
# maps/train/955.jpg
# maps/train/956.jpg
# maps/train/957.jpg
# maps/train/958.jpg
# maps/train/959.jpg
# maps/train/96.jpg
# maps/train/960.jpg
# maps/train/961.jpg
# maps/train/962.jpg
# maps/train/963.jpg
# maps/train/964.jpg
# maps/train/965.jpg
# maps/train/966.jpg
# maps/train/967.jpg
# maps/train/968.jpg
# maps/train/969.jpg
# maps/train/97.jpg
# maps/train/970.jpg
# maps/train/971.jpg
# maps/train/972.jpg
# maps/train/973.jpg
# maps/train/974.jpg
# maps/train/975.jpg
# maps/train/976.jpg
# maps/train/977.jpg
# maps/train/978.jpg
# maps/train/1036.jpg
# maps/train/1037.jpg
# maps/train/1038.jpg
# maps/train/1039.jpg
# maps/train/104.jpg
# maps/train/1040.jpg
# maps/train/1041.jpg
# maps/train/1042.jpg
# maps/train/1043.jpg
# maps/train/1044.jpg
# maps/train/1045.jpg
# maps/train/1046.jpg
# maps/train/1047.jpg
# maps/train/1048.jpg
# maps/train/1049.jpg
# maps/train/105.jpg
# maps/train/1050.jpg
# maps/train/1051.jpg
# maps/train/1052.jpg
# maps/train/1053.jpg
# maps/train/1054.jpg
# maps/train/1055.jpg
# maps/train/1056.jpg
# maps/train/1057.jpg
# maps/train/1058.jpg
# maps/train/1059.jpg
# maps/train/379.jpg
# maps/train/38.jpg
# maps/train/380.jpg
# maps/train/381.jpg
# maps/train/382.jpg
# maps/train/383.jpg
# maps/train/384.jpg
# maps/train/385.jpg
# maps/train/386.jpg
# maps/train/387.jpg
# maps/train/388.jpg
# maps/train/389.jpg
# maps/train/39.jpg
# maps/train/390.jpg
# maps/train/391.jpg
# maps/train/392.jpg
# maps/train/393.jpg
# maps/train/394.jpg
# maps/train/395.jpg
# maps/train/396.jpg
# maps/train/239.jpg
# maps/train/24.jpg
# maps/train/240.jpg
# maps/train/241.jpg
# maps/train/242.jpg
# maps/train/243.jpg
# maps/train/244.jpg
# maps/train/245.jpg
# maps/train/246.jpg
# maps/train/247.jpg
# maps/train/248.jpg
# maps/train/249.jpg
# maps/train/25.jpg
# maps/train/250.jpg
# maps/train/251.jpg
# maps/train/252.jpg
# maps/train/253.jpg
# maps/train/254.jpg
# maps/train/255.jpg
# maps/train/256.jpg
# maps/train/257.jpg
# maps/train/258.jpg
# maps/train/259.jpg
# maps/train/26.jpg
# maps/train/260.jpg
# maps/train/261.jpg
# maps/train/262.jpg
# maps/train/263.jpg
# maps/train/264.jpg
# maps/train/265.jpg
# maps/train/266.jpg
# maps/train/267.jpg
# maps/train/268.jpg
# maps/train/269.jpg
# maps/train/27.jpg
# maps/train/270.jpg
# maps/train/800.jpg
# maps/train/801.jpg
# maps/train/802.jpg
# maps/train/803.jpg
# maps/train/804.jpg
# maps/train/805.jpg
# maps/train/806.jpg
# maps/train/807.jpg
# maps/train/808.jpg
# maps/train/809.jpg
# maps/train/81.jpg
# maps/train/810.jpg
# maps/train/811.jpg
# maps/train/812.jpg
# maps/train/813.jpg
# maps/train/814.jpg
# maps/train/815.jpg
# maps/train/816.jpg
# maps/train/817.jpg
# maps/train/818.jpg
# maps/train/819.jpg
# maps/train/82.jpg
# maps/train/878.jpg
# maps/train/879.jpg
# maps/train/88.jpg
# maps/train/880.jpg
# maps/train/881.jpg
# maps/train/882.jpg
# maps/train/883.jpg
# maps/train/884.jpg
# maps/train/885.jpg
# maps/train/886.jpg
# maps/train/887.jpg
# maps/train/888.jpg
# maps/train/889.jpg
# maps/train/89.jpg
# maps/train/890.jpg
# maps/train/891.jpg
# maps/train/892.jpg
# maps/train/893.jpg
# maps/train/894.jpg
# maps/train/895.jpg
# maps/train/896.jpg
# maps/train/897.jpg
# maps/train/898.jpg
# maps/train/899.jpg
# maps/train/9.jpg
# maps/train/90.jpg
# maps/train/900.jpg
# maps/train/901.jpg
# maps/train/902.jpg
# maps/train/903.jpg
# maps/train/904.jpg
# maps/train/905.jpg
# maps/train/906.jpg
# maps/train/907.jpg
# maps/train/908.jpg
# maps/train/909.jpg
# maps/train/91.jpg
# maps/train/300.jpg
# maps/train/301.jpg
# maps/train/302.jpg
# maps/train/303.jpg
# maps/train/304.jpg
# maps/train/305.jpg
# maps/train/306.jpg
# maps/train/307.jpg
# maps/train/308.jpg
# maps/train/309.jpg
# maps/train/31.jpg
# maps/train/310.jpg
# maps/train/311.jpg
# maps/train/312.jpg
# maps/train/313.jpg
# maps/train/314.jpg
# maps/train/315.jpg
# maps/train/316.jpg
# maps/train/317.jpg
# maps/train/318.jpg
# maps/train/319.jpg
# maps/train/32.jpg
# maps/train/682.jpg
# maps/train/683.jpg
# maps/train/684.jpg
# maps/train/685.jpg
# maps/train/686.jpg
# maps/train/687.jpg
# maps/train/688.jpg
# maps/train/689.jpg
# maps/train/69.jpg
# maps/train/690.jpg
# maps/train/691.jpg
# maps/train/692.jpg
# maps/train/693.jpg
# maps/train/694.jpg
# maps/train/695.jpg
# maps/train/696.jpg
# maps/train/697.jpg
# maps/train/698.jpg
# maps/train/699.jpg
# maps/train/7.jpg
# maps/train/70.jpg
# maps/train/700.jpg
# maps/train/701.jpg
# maps/train/702.jpg
# maps/train/703.jpg
# maps/train/704.jpg
# maps/train/705.jpg
# maps/train/706.jpg
# maps/train/707.jpg
# maps/train/708.jpg
# maps/train/709.jpg
# maps/train/71.jpg
# maps/train/710.jpg
# maps/train/711.jpg
# maps/train/455.jpg
# maps/train/456.jpg
# maps/train/457.jpg
# maps/train/458.jpg
# maps/train/459.jpg
# maps/train/46.jpg
# maps/train/460.jpg
# maps/train/461.jpg
# maps/train/462.jpg
# maps/train/463.jpg
# maps/train/464.jpg
# maps/train/465.jpg
# maps/train/466.jpg
# maps/train/467.jpg
# maps/train/468.jpg
# maps/train/469.jpg
# maps/train/47.jpg
# maps/train/470.jpg
# maps/train/471.jpg
# maps/train/472.jpg
# maps/train/473.jpg
# maps/train/474.jpg
# maps/train/475.jpg
# maps/train/476.jpg
# maps/train/477.jpg
# maps/train/478.jpg
# maps/train/479.jpg
# maps/train/48.jpg
# maps/train/480.jpg
# maps/train/481.jpg
# maps/train/482.jpg
# maps/train/483.jpg
# maps/train/484.jpg
# maps/train/485.jpg
# maps/train/486.jpg
# maps/train/487.jpg
# maps/train/488.jpg
# maps/train/173.jpg
# maps/train/174.jpg
# maps/train/175.jpg
# maps/train/176.jpg
# maps/train/177.jpg
# maps/train/178.jpg
# maps/train/179.jpg
# maps/train/18.jpg
# maps/train/180.jpg
# maps/train/181.jpg
# maps/train/182.jpg
# maps/train/183.jpg
# maps/train/184.jpg
# maps/train/185.jpg
# maps/train/186.jpg
# maps/train/187.jpg
# maps/train/188.jpg
# maps/train/189.jpg
# maps/train/19.jpg
# maps/train/190.jpg
# maps/train/191.jpg
# maps/train/192.jpg
# maps/train/193.jpg
# maps/train/194.jpg
# maps/train/195.jpg
# maps/train/196.jpg
# maps/train/197.jpg
# maps/train/198.jpg
# maps/train/199.jpg
# maps/train/2.jpg
# maps/train/20.jpg
# maps/train/200.jpg
# maps/train/62.jpg
# maps/train/620.jpg
# maps/train/621.jpg
# maps/train/622.jpg
# maps/train/623.jpg
# maps/train/624.jpg
# maps/train/625.jpg
# maps/train/626.jpg
# maps/train/627.jpg
# maps/train/628.jpg
# maps/train/629.jpg
# maps/train/63.jpg
# maps/train/630.jpg
# maps/train/631.jpg
# maps/train/632.jpg
# maps/train/633.jpg
# maps/train/634.jpg
# maps/train/635.jpg
# maps/train/636.jpg
# maps/train/637.jpg
# maps/train/638.jpg
# maps/train/639.jpg
# maps/train/64.jpg
# maps/train/640.jpg
# maps/train/641.jpg
# maps/train/642.jpg
# maps/train/643.jpg
# maps/train/644.jpg
# maps/train/645.jpg
# maps/train/646.jpg
# maps/train/647.jpg
# maps/train/563.jpg
# maps/train/564.jpg
# maps/train/565.jpg
# maps/train/566.jpg
# maps/train/567.jpg
# maps/train/568.jpg
# maps/train/569.jpg
# maps/train/57.jpg
# maps/train/570.jpg
# maps/train/571.jpg
# maps/train/572.jpg
# maps/train/573.jpg
# maps/train/574.jpg
# maps/train/575.jpg
# maps/train/576.jpg
# maps/train/577.jpg
# maps/train/578.jpg
# maps/train/579.jpg
# maps/train/58.jpg
# maps/train/580.jpg
# maps/train/581.jpg
# maps/train/582.jpg
# maps/train/583.jpg
# maps/train/584.jpg
# maps/train/585.jpg
# maps/train/586.jpg
# maps/train/587.jpg
# maps/train/588.jpg
# maps/train/589.jpg
# maps/train/933.jpg
# maps/train/934.jpg
# maps/train/935.jpg
# maps/train/936.jpg
# maps/train/937.jpg
# maps/train/938.jpg
# maps/train/939.jpg
# maps/train/94.jpg
# maps/train/940.jpg
# maps/train/941.jpg
# maps/train/942.jpg
# maps/train/943.jpg
# maps/train/944.jpg
# maps/train/945.jpg
# maps/train/946.jpg
# maps/train/947.jpg
# maps/train/948.jpg
# maps/train/949.jpg
# maps/train/95.jpg
# maps/train/950.jpg
# maps/train/951.jpg
# maps/train/952.jpg
# maps/train/119.jpg
# maps/train/12.jpg
# maps/train/120.jpg
# maps/train/121.jpg
# maps/train/122.jpg
# maps/train/123.jpg
# maps/train/124.jpg
# maps/train/125.jpg
# maps/train/126.jpg
# maps/train/127.jpg
# maps/train/128.jpg
# maps/train/129.jpg
# maps/train/13.jpg
# maps/train/130.jpg
# maps/train/131.jpg
# maps/train/132.jpg
# maps/train/133.jpg
# maps/train/134.jpg
# maps/train/135.jpg
# maps/train/136.jpg
# maps/train/137.jpg
# maps/train/138.jpg
# maps/train/139.jpg
# maps/train/14.jpg
# maps/train/140.jpg
# maps/train/398.jpg
# maps/train/399.jpg
# maps/train/4.jpg
# maps/train/40.jpg
# maps/train/400.jpg
# maps/train/401.jpg
# maps/train/402.jpg
# maps/train/403.jpg
# maps/train/404.jpg
# maps/train/405.jpg
# maps/train/406.jpg
# maps/train/407.jpg
# maps/train/408.jpg
# maps/train/409.jpg
# maps/train/41.jpg
# maps/train/410.jpg
# maps/train/411.jpg
# maps/train/412.jpg
# maps/train/413.jpg
# maps/train/414.jpg
# maps/train/415.jpg
# maps/train/416.jpg
# maps/train/417.jpg
# maps/train/418.jpg
# maps/train/419.jpg
# maps/train/1060.jpg
# maps/train/1061.jpg
# maps/train/1062.jpg
# maps/train/1063.jpg
# maps/train/1064.jpg
# maps/train/1065.jpg
# maps/train/1066.jpg
# maps/train/1067.jpg
# maps/train/1068.jpg
# maps/train/1069.jpg
# maps/train/107.jpg
# maps/train/1070.jpg
# maps/train/1071.jpg
# maps/train/1072.jpg
# maps/train/1073.jpg
# maps/train/1074.jpg
# maps/train/1075.jpg
# maps/train/1076.jpg
# maps/train/1077.jpg
# maps/train/1078.jpg
# maps/train/1079.jpg
# maps/train/108.jpg
# maps/train/98.jpg
# maps/train/980.jpg
# maps/train/981.jpg
# maps/train/982.jpg
# maps/train/983.jpg
# maps/train/984.jpg
# maps/train/985.jpg
# maps/train/986.jpg
# maps/train/987.jpg
# maps/train/988.jpg
# maps/train/989.jpg
# maps/train/99.jpg
# maps/train/990.jpg
# maps/train/991.jpg
# maps/train/992.jpg
# maps/train/993.jpg
# maps/train/994.jpg
# maps/train/995.jpg
# maps/train/996.jpg
# maps/train/997.jpg
# maps/train/998.jpg
# maps/train/999.jpg
# maps/train/780.jpg
# maps/train/781.jpg
# maps/train/782.jpg
# maps/train/783.jpg
# maps/train/784.jpg
# maps/train/785.jpg
# maps/train/786.jpg
# maps/train/787.jpg
# maps/train/788.jpg
# maps/train/789.jpg
# maps/train/79.jpg
# maps/train/790.jpg
# maps/train/791.jpg
# maps/train/792.jpg
# maps/train/793.jpg
# maps/train/794.jpg
# maps/train/795.jpg
# maps/train/796.jpg
# maps/train/797.jpg
# maps/train/798.jpg
# maps/train/799.jpg
# maps/train/8.jpg
# maps/train/821.jpg
# maps/train/822.jpg
# maps/train/823.jpg
# maps/train/824.jpg
# maps/train/825.jpg
# maps/train/826.jpg
# maps/train/827.jpg
# maps/train/828.jpg
# maps/train/829.jpg
# maps/train/83.jpg
# maps/train/830.jpg
# maps/train/831.jpg
# maps/train/832.jpg
# maps/train/833.jpg
# maps/train/834.jpg
# maps/train/835.jpg
# maps/train/836.jpg
# maps/train/837.jpg
# maps/train/838.jpg
# maps/train/839.jpg
# maps/train/84.jpg
# maps/train/840.jpg
# maps/train/841.jpg
# maps/train/842.jpg
# maps/train/735.jpg
# maps/train/736.jpg
# maps/train/737.jpg
# maps/train/738.jpg
# maps/train/739.jpg
# maps/train/74.jpg
# maps/train/740.jpg
# maps/train/741.jpg
# maps/train/742.jpg
# maps/train/743.jpg
# maps/train/744.jpg
# maps/train/745.jpg
# maps/train/746.jpg
# maps/train/747.jpg
# maps/train/748.jpg
# maps/train/749.jpg
# maps/train/75.jpg
# maps/train/750.jpg
# maps/train/751.jpg
# maps/train/752.jpg
# maps/train/753.jpg
# maps/train/754.jpg
# maps/train/755.jpg
# maps/train/51.jpg
# maps/train/510.jpg
# maps/train/511.jpg
# maps/train/512.jpg
# maps/train/513.jpg
# maps/train/514.jpg
# maps/train/515.jpg
# maps/train/516.jpg
# maps/train/517.jpg
# maps/train/518.jpg
# maps/train/519.jpg
# maps/train/52.jpg
# maps/train/520.jpg
# maps/train/521.jpg
# maps/train/522.jpg
# maps/train/523.jpg
# maps/train/524.jpg
# maps/train/525.jpg
# maps/train/526.jpg
# maps/train/527.jpg
# maps/train/528.jpg
# maps/train/529.jpg
# maps/train/321.jpg
# maps/train/322.jpg
# maps/train/323.jpg
# maps/train/324.jpg
# maps/train/325.jpg
# maps/train/326.jpg
# maps/train/327.jpg
# maps/train/328.jpg
# maps/train/329.jpg
# maps/train/33.jpg
# maps/train/330.jpg
# maps/train/331.jpg
# maps/train/332.jpg
# maps/train/333.jpg
# maps/train/334.jpg
# maps/train/335.jpg
# maps/train/336.jpg
# maps/train/337.jpg
# maps/train/338.jpg
# maps/train/339.jpg
# maps/train/1017.jpg
# maps/train/1018.jpg
# maps/train/1019.jpg
# maps/train/102.jpg
# maps/train/1020.jpg
# maps/train/1021.jpg
# maps/train/1022.jpg
# maps/train/1023.jpg
# maps/train/1024.jpg
# maps/train/1025.jpg
# maps/train/1026.jpg
# maps/train/1027.jpg
# maps/train/1028.jpg
# maps/train/1029.jpg
# maps/train/103.jpg
# maps/train/1030.jpg
# maps/train/1031.jpg
# maps/train/1032.jpg
# maps/train/1033.jpg
# maps/train/1034.jpg
# maps/val/
# maps/val/509.jpg
# maps/val/1.jpg
# maps/val/10.jpg
# maps/val/100.jpg
# maps/val/1000.jpg
# maps/val/1001.jpg
# maps/val/1002.jpg
# maps/val/1003.jpg
# maps/val/1004.jpg
# maps/val/1005.jpg
# maps/val/1006.jpg
# maps/val/1007.jpg
# maps/val/1008.jpg
# maps/val/1009.jpg
# maps/val/101.jpg
# maps/val/1010.jpg
# maps/val/1011.jpg
# maps/val/1012.jpg
# maps/val/1013.jpg
# maps/val/1014.jpg
# maps/val/1015.jpg
# maps/val/530.jpg
# maps/val/531.jpg
# maps/val/532.jpg
# maps/val/533.jpg
# maps/val/534.jpg
# maps/val/535.jpg
# maps/val/536.jpg
# maps/val/537.jpg
# maps/val/538.jpg
# maps/val/539.jpg
# maps/val/54.jpg
# maps/val/540.jpg
# maps/val/541.jpg
# maps/val/542.jpg
# maps/val/543.jpg
# maps/val/544.jpg
# maps/val/545.jpg
# maps/val/546.jpg
# maps/val/547.jpg
# maps/val/548.jpg
# maps/val/549.jpg
# maps/val/55.jpg
# maps/val/550.jpg
# maps/val/551.jpg
# maps/val/552.jpg
# maps/val/553.jpg
# maps/val/554.jpg
# maps/val/555.jpg
# maps/val/556.jpg
# maps/val/557.jpg
# maps/val/558.jpg
# maps/val/559.jpg
# maps/val/56.jpg
# maps/val/560.jpg
# maps/val/561.jpg
# maps/val/757.jpg
# maps/val/758.jpg
# maps/val/759.jpg
# maps/val/76.jpg
# maps/val/760.jpg
# maps/val/761.jpg
# maps/val/762.jpg
# maps/val/763.jpg
# maps/val/764.jpg
# maps/val/765.jpg
# maps/val/766.jpg
# maps/val/767.jpg
# maps/val/768.jpg
# maps/val/769.jpg
# maps/val/77.jpg
# maps/val/770.jpg
# maps/val/771.jpg
# maps/val/772.jpg
# maps/val/773.jpg
# maps/val/774.jpg
# maps/val/775.jpg
# maps/val/776.jpg
# maps/val/777.jpg
# maps/val/778.jpg
# maps/val/779.jpg
# maps/val/327.jpg
# maps/val/328.jpg
# maps/val/329.jpg
# maps/val/33.jpg
# maps/val/330.jpg
# maps/val/331.jpg
# maps/val/332.jpg
# maps/val/333.jpg
# maps/val/334.jpg
# maps/val/335.jpg
# maps/val/336.jpg
# maps/val/337.jpg
# maps/val/338.jpg
# maps/val/339.jpg
# maps/val/34.jpg
# maps/val/340.jpg
# maps/val/341.jpg
# maps/val/342.jpg
# maps/val/343.jpg
# maps/val/344.jpg
# maps/val/345.jpg
# maps/val/346.jpg
# maps/val/347.jpg
# maps/val/348.jpg
# maps/val/349.jpg
# maps/val/35.jpg
# maps/val/197.jpg
# maps/val/198.jpg
# maps/val/199.jpg
# maps/val/2.jpg
# maps/val/20.jpg
# maps/val/200.jpg
# maps/val/201.jpg
# maps/val/202.jpg
# maps/val/203.jpg
# maps/val/204.jpg
# maps/val/205.jpg
# maps/val/206.jpg
# maps/val/207.jpg
# maps/val/208.jpg
# maps/val/209.jpg
# maps/val/21.jpg
# maps/val/210.jpg
# maps/val/211.jpg
# maps/val/212.jpg
# maps/val/213.jpg
# maps/val/214.jpg
# maps/val/1016.jpg
# maps/val/1035.jpg
# maps/val/106.jpg
# maps/val/1080.jpg
# maps/val/117.jpg
# maps/val/140.jpg
# maps/val/17.jpg
# maps/val/196.jpg
# maps/val/215.jpg
# maps/val/235.jpg
# maps/val/266.jpg
# maps/val/292.jpg
# maps/val/326.jpg
# maps/val/350.jpg
# maps/val/373.jpg
# maps/val/392.jpg
# maps/val/412.jpg
# maps/val/446.jpg
# maps/val/468.jpg
# maps/val/489.jpg
# maps/val/911.jpg
# maps/val/912.jpg
# maps/val/913.jpg
# maps/val/914.jpg
# maps/val/915.jpg
# maps/val/916.jpg
# maps/val/917.jpg
# maps/val/918.jpg
# maps/val/919.jpg
# maps/val/92.jpg
# maps/val/920.jpg
# maps/val/921.jpg
# maps/val/922.jpg
# maps/val/923.jpg
# maps/val/924.jpg
# maps/val/925.jpg
# maps/val/926.jpg
# maps/val/927.jpg
# maps/val/928.jpg
# maps/val/929.jpg
# maps/val/93.jpg
# maps/val/930.jpg
# maps/val/931.jpg
# maps/val/413.jpg
# maps/val/414.jpg
# maps/val/415.jpg
# maps/val/416.jpg
# maps/val/417.jpg
# maps/val/418.jpg
# maps/val/419.jpg
# maps/val/42.jpg
# maps/val/420.jpg
# maps/val/421.jpg
# maps/val/422.jpg
# maps/val/423.jpg
# maps/val/424.jpg
# maps/val/425.jpg
# maps/val/426.jpg
# maps/val/427.jpg
# maps/val/428.jpg
# maps/val/429.jpg
# maps/val/43.jpg
# maps/val/430.jpg
# maps/val/431.jpg
# maps/val/432.jpg
# maps/val/433.jpg
# maps/val/434.jpg
# maps/val/435.jpg
# maps/val/436.jpg
# maps/val/437.jpg
# maps/val/438.jpg
# maps/val/439.jpg
# maps/val/44.jpg
# maps/val/440.jpg
# maps/val/441.jpg
# maps/val/442.jpg
# maps/val/443.jpg
# maps/val/444.jpg
# maps/val/445.jpg
# maps/val/649.jpg
# maps/val/65.jpg
# maps/val/650.jpg
# maps/val/651.jpg
# maps/val/652.jpg
# maps/val/653.jpg
# maps/val/654.jpg
# maps/val/655.jpg
# maps/val/656.jpg
# maps/val/657.jpg
# maps/val/658.jpg
# maps/val/659.jpg
# maps/val/66.jpg
# maps/val/660.jpg
# maps/val/661.jpg
# maps/val/662.jpg
# maps/val/663.jpg
# maps/val/664.jpg
# maps/val/665.jpg
# maps/val/666.jpg
# maps/val/667.jpg
# maps/val/668.jpg
# maps/val/669.jpg
# maps/val/67.jpg
# maps/val/670.jpg
# maps/val/671.jpg
# maps/val/672.jpg
# maps/val/673.jpg
# maps/val/674.jpg
# maps/val/675.jpg
# maps/val/676.jpg
# maps/val/677.jpg
# maps/val/678.jpg
# maps/val/679.jpg
# maps/val/68.jpg
# maps/val/680.jpg
# maps/val/844.jpg
# maps/val/845.jpg
# maps/val/846.jpg
# maps/val/847.jpg
# maps/val/848.jpg
# maps/val/849.jpg
# maps/val/85.jpg
# maps/val/850.jpg
# maps/val/851.jpg
# maps/val/852.jpg
# maps/val/853.jpg
# maps/val/854.jpg
# maps/val/855.jpg
# maps/val/856.jpg
# maps/val/857.jpg
# maps/val/858.jpg
# maps/val/859.jpg
# maps/val/86.jpg
# maps/val/860.jpg
# maps/val/861.jpg
# maps/val/862.jpg
# maps/val/863.jpg
# maps/val/864.jpg
# maps/val/865.jpg
# maps/val/866.jpg
# maps/val/867.jpg
# maps/val/868.jpg
# maps/val/869.jpg
# maps/val/87.jpg
# maps/val/870.jpg
# maps/val/871.jpg
# maps/val/872.jpg
# maps/val/873.jpg
# maps/val/874.jpg
# maps/val/875.jpg
# maps/val/876.jpg
# maps/val/1081.jpg
# maps/val/1082.jpg
# maps/val/1083.jpg
# maps/val/1084.jpg
# maps/val/1085.jpg
# maps/val/1086.jpg
# maps/val/1087.jpg
# maps/val/1088.jpg
# maps/val/1089.jpg
# maps/val/109.jpg
# maps/val/1090.jpg
# maps/val/1091.jpg
# maps/val/1092.jpg
# maps/val/1093.jpg
# maps/val/1094.jpg
# maps/val/1095.jpg
# maps/val/1096.jpg
# maps/val/1097.jpg
# maps/val/1098.jpg
# maps/val/11.jpg
# maps/val/110.jpg
# maps/val/111.jpg
# maps/val/112.jpg
# maps/val/113.jpg
# maps/val/114.jpg
# maps/val/115.jpg
# maps/val/116.jpg
# maps/val/267.jpg
# maps/val/268.jpg
# maps/val/269.jpg
# maps/val/27.jpg
# maps/val/270.jpg
# maps/val/271.jpg
# maps/val/272.jpg
# maps/val/273.jpg
# maps/val/274.jpg
# maps/val/275.jpg
# maps/val/276.jpg
# maps/val/277.jpg
# maps/val/278.jpg
# maps/val/279.jpg
# maps/val/28.jpg
# maps/val/280.jpg
# maps/val/281.jpg
# maps/val/282.jpg
# maps/val/283.jpg
# maps/val/284.jpg
# maps/val/285.jpg
# maps/val/286.jpg
# maps/val/287.jpg
# maps/val/288.jpg
# maps/val/289.jpg
# maps/val/29.jpg
# maps/val/290.jpg
# maps/val/291.jpg
# maps/val/713.jpg
# maps/val/714.jpg
# maps/val/715.jpg
# maps/val/716.jpg
# maps/val/717.jpg
# maps/val/718.jpg
# maps/val/719.jpg
# maps/val/72.jpg
# maps/val/720.jpg
# maps/val/721.jpg
# maps/val/722.jpg
# maps/val/723.jpg
# maps/val/724.jpg
# maps/val/725.jpg
# maps/val/726.jpg
# maps/val/727.jpg
# maps/val/728.jpg
# maps/val/729.jpg
# maps/val/73.jpg
# maps/val/730.jpg
# maps/val/731.jpg
# maps/val/732.jpg
# maps/val/733.jpg
# maps/val/49.jpg
# maps/val/490.jpg
# maps/val/491.jpg
# maps/val/492.jpg
# maps/val/493.jpg
# maps/val/494.jpg
# maps/val/495.jpg
# maps/val/496.jpg
# maps/val/497.jpg
# maps/val/498.jpg
# maps/val/499.jpg
# maps/val/5.jpg
# maps/val/50.jpg
# maps/val/500.jpg
# maps/val/501.jpg
# maps/val/502.jpg
# maps/val/503.jpg
# maps/val/504.jpg
# maps/val/505.jpg
# maps/val/506.jpg
# maps/val/507.jpg
# maps/val/508.jpg
# maps/val/590.jpg
# maps/val/591.jpg
# maps/val/592.jpg
# maps/val/593.jpg
# maps/val/594.jpg
# maps/val/595.jpg
# maps/val/596.jpg
# maps/val/597.jpg
# maps/val/598.jpg
# maps/val/599.jpg
# maps/val/6.jpg
# maps/val/60.jpg
# maps/val/600.jpg
# maps/val/601.jpg
# maps/val/602.jpg
# maps/val/603.jpg
# maps/val/604.jpg
# maps/val/605.jpg
# maps/val/606.jpg
# maps/val/607.jpg
# maps/val/608.jpg
# maps/val/609.jpg
# maps/val/61.jpg
# maps/val/610.jpg
# maps/val/611.jpg
# maps/val/612.jpg
# maps/val/613.jpg
# maps/val/614.jpg
# maps/val/615.jpg
# maps/val/616.jpg
# maps/val/617.jpg
# maps/val/618.jpg
# maps/val/141.jpg
# maps/val/142.jpg
# maps/val/143.jpg
# maps/val/144.jpg
# maps/val/145.jpg
# maps/val/146.jpg
# maps/val/147.jpg
# maps/val/148.jpg
# maps/val/149.jpg
# maps/val/15.jpg
# maps/val/150.jpg
# maps/val/151.jpg
# maps/val/152.jpg
# maps/val/153.jpg
# maps/val/154.jpg
# maps/val/155.jpg
# maps/val/156.jpg
# maps/val/157.jpg
# maps/val/158.jpg
# maps/val/159.jpg
# maps/val/16.jpg
# maps/val/160.jpg
# maps/val/161.jpg
# maps/val/162.jpg
# maps/val/163.jpg
# maps/val/164.jpg
# maps/val/165.jpg
# maps/val/166.jpg
# maps/val/167.jpg
# maps/val/168.jpg
# maps/val/169.jpg
# maps/val/954.jpg
# maps/val/955.jpg
# maps/val/956.jpg
# maps/val/957.jpg
# maps/val/958.jpg
# maps/val/959.jpg
# maps/val/96.jpg
# maps/val/960.jpg
# maps/val/961.jpg
# maps/val/962.jpg
# maps/val/963.jpg
# maps/val/964.jpg
# maps/val/965.jpg
# maps/val/966.jpg
# maps/val/967.jpg
# maps/val/968.jpg
# maps/val/969.jpg
# maps/val/97.jpg
# maps/val/970.jpg
# maps/val/971.jpg
# maps/val/972.jpg
# maps/val/973.jpg
# maps/val/974.jpg
# maps/val/975.jpg
# maps/val/976.jpg
# maps/val/977.jpg
# maps/val/978.jpg
# maps/val/374.jpg
# maps/val/375.jpg
# maps/val/376.jpg
# maps/val/377.jpg
# maps/val/378.jpg
# maps/val/379.jpg
# maps/val/38.jpg
# maps/val/380.jpg
# maps/val/381.jpg
# maps/val/382.jpg
# maps/val/383.jpg
# maps/val/384.jpg
# maps/val/385.jpg
# maps/val/386.jpg
# maps/val/387.jpg
# maps/val/388.jpg
# maps/val/389.jpg
# maps/val/39.jpg
# maps/val/390.jpg
# maps/val/391.jpg
# maps/val/1036.jpg
# maps/val/1037.jpg
# maps/val/1038.jpg
# maps/val/1039.jpg
# maps/val/104.jpg
# maps/val/1040.jpg
# maps/val/1041.jpg
# maps/val/1042.jpg
# maps/val/1043.jpg
# maps/val/1044.jpg
# maps/val/1045.jpg
# maps/val/1046.jpg
# maps/val/1047.jpg
# maps/val/1048.jpg
# maps/val/1049.jpg
# maps/val/105.jpg
# maps/val/1050.jpg
# maps/val/1051.jpg
# maps/val/1052.jpg
# maps/val/1053.jpg
# maps/val/1054.jpg
# maps/val/1055.jpg
# maps/val/1056.jpg
# maps/val/1057.jpg
# maps/val/1058.jpg
# maps/val/1059.jpg
# maps/val/800.jpg
# maps/val/801.jpg
# maps/val/802.jpg
# maps/val/803.jpg
# maps/val/804.jpg
# maps/val/805.jpg
# maps/val/806.jpg
# maps/val/807.jpg
# maps/val/808.jpg
# maps/val/809.jpg
# maps/val/81.jpg
# maps/val/810.jpg
# maps/val/811.jpg
# maps/val/812.jpg
# maps/val/813.jpg
# maps/val/814.jpg
# maps/val/815.jpg
# maps/val/816.jpg
# maps/val/817.jpg
# maps/val/818.jpg
# maps/val/819.jpg
# maps/val/82.jpg
# maps/val/236.jpg
# maps/val/237.jpg
# maps/val/238.jpg
# maps/val/239.jpg
# maps/val/24.jpg
# maps/val/240.jpg
# maps/val/241.jpg
# maps/val/242.jpg
# maps/val/243.jpg
# maps/val/244.jpg
# maps/val/245.jpg
# maps/val/246.jpg
# maps/val/247.jpg
# maps/val/248.jpg
# maps/val/249.jpg
# maps/val/25.jpg
# maps/val/250.jpg
# maps/val/251.jpg
# maps/val/252.jpg
# maps/val/253.jpg
# maps/val/254.jpg
# maps/val/255.jpg
# maps/val/256.jpg
# maps/val/257.jpg
# maps/val/258.jpg
# maps/val/259.jpg
# maps/val/26.jpg
# maps/val/260.jpg
# maps/val/261.jpg
# maps/val/262.jpg
# maps/val/263.jpg
# maps/val/264.jpg
# maps/val/265.jpg
# maps/val/878.jpg
# maps/val/879.jpg
# maps/val/88.jpg
# maps/val/880.jpg
# maps/val/881.jpg
# maps/val/882.jpg
# maps/val/883.jpg
# maps/val/884.jpg
# maps/val/885.jpg
# maps/val/886.jpg
# maps/val/887.jpg
# maps/val/888.jpg
# maps/val/889.jpg
# maps/val/89.jpg
# maps/val/890.jpg
# maps/val/891.jpg
# maps/val/892.jpg
# maps/val/893.jpg
# maps/val/894.jpg
# maps/val/895.jpg
# maps/val/896.jpg
# maps/val/897.jpg
# maps/val/898.jpg
# maps/val/899.jpg
# maps/val/9.jpg
# maps/val/90.jpg
# maps/val/900.jpg
# maps/val/901.jpg
# maps/val/902.jpg
# maps/val/903.jpg
# maps/val/904.jpg
# maps/val/905.jpg
# maps/val/906.jpg
# maps/val/907.jpg
# maps/val/908.jpg
# maps/val/909.jpg
# maps/val/91.jpg
# maps/val/447.jpg
# maps/val/448.jpg
# maps/val/449.jpg
# maps/val/45.jpg
# maps/val/450.jpg
# maps/val/451.jpg
# maps/val/452.jpg
# maps/val/453.jpg
# maps/val/454.jpg
# maps/val/455.jpg
# maps/val/456.jpg
# maps/val/457.jpg
# maps/val/458.jpg
# maps/val/459.jpg
# maps/val/46.jpg
# maps/val/460.jpg
# maps/val/461.jpg
# maps/val/462.jpg
# maps/val/463.jpg
# maps/val/464.jpg
# maps/val/465.jpg
# maps/val/466.jpg
# maps/val/467.jpg
# maps/val/682.jpg
# maps/val/683.jpg
# maps/val/684.jpg
# maps/val/685.jpg
# maps/val/686.jpg
# maps/val/687.jpg
# maps/val/688.jpg
# maps/val/689.jpg
# maps/val/69.jpg
# maps/val/690.jpg
# maps/val/691.jpg
# maps/val/692.jpg
# maps/val/693.jpg
# maps/val/694.jpg
# maps/val/695.jpg
# maps/val/696.jpg
# maps/val/697.jpg
# maps/val/698.jpg
# maps/val/699.jpg
# maps/val/7.jpg
# maps/val/70.jpg
# maps/val/700.jpg
# maps/val/701.jpg
# maps/val/702.jpg
# maps/val/703.jpg
# maps/val/704.jpg
# maps/val/705.jpg
# maps/val/706.jpg
# maps/val/707.jpg
# maps/val/708.jpg
# maps/val/709.jpg
# maps/val/71.jpg
# maps/val/710.jpg
# maps/val/711.jpg
# maps/val/293.jpg
# maps/val/294.jpg
# maps/val/295.jpg
# maps/val/296.jpg
# maps/val/297.jpg
# maps/val/298.jpg
# maps/val/299.jpg
# maps/val/3.jpg
# maps/val/30.jpg
# maps/val/300.jpg
# maps/val/301.jpg
# maps/val/302.jpg
# maps/val/303.jpg
# maps/val/304.jpg
# maps/val/305.jpg
# maps/val/306.jpg
# maps/val/307.jpg
# maps/val/308.jpg
# maps/val/309.jpg
# maps/val/31.jpg
# maps/val/310.jpg
# maps/val/311.jpg
# maps/val/312.jpg
# maps/val/313.jpg
# maps/val/314.jpg
# maps/val/315.jpg
# maps/val/316.jpg
# maps/val/317.jpg
# maps/val/318.jpg
# maps/val/319.jpg
# maps/val/32.jpg
# maps/val/320.jpg
# maps/val/321.jpg
# maps/val/322.jpg
# maps/val/323.jpg
# maps/val/324.jpg
# maps/val/325.jpg
# maps/val/62.jpg
# maps/val/620.jpg
# maps/val/621.jpg
# maps/val/622.jpg
# maps/val/623.jpg
# maps/val/624.jpg
# maps/val/625.jpg
# maps/val/626.jpg
# maps/val/627.jpg
# maps/val/628.jpg
# maps/val/629.jpg
# maps/val/63.jpg
# maps/val/630.jpg
# maps/val/631.jpg
# maps/val/632.jpg
# maps/val/633.jpg
# maps/val/634.jpg
# maps/val/635.jpg
# maps/val/636.jpg
# maps/val/637.jpg
# maps/val/638.jpg
# maps/val/639.jpg
# maps/val/64.jpg
# maps/val/640.jpg
# maps/val/641.jpg
# maps/val/642.jpg
# maps/val/643.jpg
# maps/val/644.jpg
# maps/val/645.jpg
# maps/val/646.jpg
# maps/val/647.jpg
# maps/val/170.jpg
# maps/val/171.jpg
# maps/val/172.jpg
# maps/val/173.jpg
# maps/val/174.jpg
# maps/val/175.jpg
# maps/val/176.jpg
# maps/val/177.jpg
# maps/val/178.jpg
# maps/val/179.jpg
# maps/val/18.jpg
# maps/val/180.jpg
# maps/val/181.jpg
# maps/val/182.jpg
# maps/val/183.jpg
# maps/val/184.jpg
# maps/val/185.jpg
# maps/val/186.jpg
# maps/val/187.jpg
# maps/val/188.jpg
# maps/val/189.jpg
# maps/val/19.jpg
# maps/val/190.jpg
# maps/val/191.jpg
# maps/val/192.jpg
# maps/val/193.jpg
# maps/val/194.jpg
# maps/val/195.jpg
# maps/val/563.jpg
# maps/val/564.jpg
# maps/val/565.jpg
# maps/val/566.jpg
# maps/val/567.jpg
# maps/val/568.jpg
# maps/val/569.jpg
# maps/val/57.jpg
# maps/val/570.jpg
# maps/val/571.jpg
# maps/val/572.jpg
# maps/val/573.jpg
# maps/val/574.jpg
# maps/val/575.jpg
# maps/val/576.jpg
# maps/val/577.jpg
# maps/val/578.jpg
# maps/val/579.jpg
# maps/val/58.jpg
# maps/val/580.jpg
# maps/val/581.jpg
# maps/val/582.jpg
# maps/val/583.jpg
# maps/val/584.jpg
# maps/val/585.jpg
# maps/val/586.jpg
# maps/val/587.jpg
# maps/val/588.jpg
# maps/val/589.jpg
# maps/val/933.jpg
# maps/val/934.jpg
# maps/val/935.jpg
# maps/val/936.jpg
# maps/val/937.jpg
# maps/val/938.jpg
# maps/val/939.jpg
# maps/val/94.jpg
# maps/val/940.jpg
# maps/val/941.jpg
# maps/val/942.jpg
# maps/val/943.jpg
# maps/val/944.jpg
# maps/val/945.jpg
# maps/val/946.jpg
# maps/val/947.jpg
# maps/val/948.jpg
# maps/val/949.jpg
# maps/val/95.jpg
# maps/val/950.jpg
# maps/val/951.jpg
# maps/val/952.jpg
# maps/val/351.jpg
# maps/val/352.jpg
# maps/val/353.jpg
# maps/val/354.jpg
# maps/val/355.jpg
# maps/val/356.jpg
# maps/val/357.jpg
# maps/val/358.jpg
# maps/val/359.jpg
# maps/val/36.jpg
# maps/val/360.jpg
# maps/val/361.jpg
# maps/val/362.jpg
# maps/val/363.jpg
# maps/val/364.jpg
# maps/val/365.jpg
# maps/val/366.jpg
# maps/val/367.jpg
# maps/val/368.jpg
# maps/val/369.jpg
# maps/val/37.jpg
# maps/val/370.jpg
# maps/val/371.jpg
# maps/val/372.jpg
# maps/val/118.jpg
# maps/val/119.jpg
# maps/val/12.jpg
# maps/val/120.jpg
# maps/val/121.jpg
# maps/val/122.jpg
# maps/val/123.jpg
# maps/val/124.jpg
# maps/val/125.jpg
# maps/val/126.jpg
# maps/val/127.jpg
# maps/val/128.jpg
# maps/val/129.jpg
# maps/val/13.jpg
# maps/val/130.jpg
# maps/val/131.jpg
# maps/val/132.jpg
# maps/val/133.jpg
# maps/val/134.jpg
# maps/val/135.jpg
# maps/val/136.jpg
# maps/val/137.jpg
# maps/val/138.jpg
# maps/val/139.jpg
# maps/val/14.jpg
# maps/val/1060.jpg
# maps/val/1061.jpg
# maps/val/1062.jpg
# maps/val/1063.jpg
# maps/val/1064.jpg
# maps/val/1065.jpg
# maps/val/1066.jpg
# maps/val/1067.jpg
# maps/val/1068.jpg
# maps/val/1069.jpg
# maps/val/107.jpg
# maps/val/1070.jpg
# maps/val/1071.jpg
# maps/val/1072.jpg
# maps/val/1073.jpg
# maps/val/1074.jpg
# maps/val/1075.jpg
# maps/val/1076.jpg
# maps/val/1077.jpg
# maps/val/1078.jpg
# maps/val/1079.jpg
# maps/val/108.jpg
# maps/val/98.jpg
# maps/val/980.jpg
# maps/val/981.jpg
# maps/val/982.jpg
# maps/val/983.jpg
# maps/val/984.jpg
# maps/val/985.jpg
# maps/val/986.jpg
# maps/val/987.jpg
# maps/val/988.jpg
# maps/val/989.jpg
# maps/val/99.jpg
# maps/val/990.jpg
# maps/val/991.jpg
# maps/val/992.jpg
# maps/val/993.jpg
# maps/val/994.jpg
# maps/val/995.jpg
# maps/val/996.jpg
# maps/val/997.jpg
# maps/val/998.jpg
# maps/val/999.jpg
# maps/val/780.jpg
# maps/val/781.jpg
# maps/val/782.jpg
# maps/val/783.jpg
# maps/val/784.jpg
# maps/val/785.jpg
# maps/val/786.jpg
# maps/val/787.jpg
# maps/val/788.jpg
# maps/val/789.jpg
# maps/val/79.jpg
# maps/val/790.jpg
# maps/val/791.jpg
# maps/val/792.jpg
# maps/val/793.jpg
# maps/val/794.jpg
# maps/val/795.jpg
# maps/val/796.jpg
# maps/val/797.jpg
# maps/val/798.jpg
# maps/val/799.jpg
# maps/val/8.jpg
# maps/val/821.jpg
# maps/val/822.jpg
# maps/val/823.jpg
# maps/val/824.jpg
# maps/val/825.jpg
# maps/val/826.jpg
# maps/val/827.jpg
# maps/val/828.jpg
# maps/val/829.jpg
# maps/val/83.jpg
# maps/val/830.jpg
# maps/val/831.jpg
# maps/val/832.jpg
# maps/val/833.jpg
# maps/val/834.jpg
# maps/val/835.jpg
# maps/val/836.jpg
# maps/val/837.jpg
# maps/val/838.jpg
# maps/val/839.jpg
# maps/val/84.jpg
# maps/val/840.jpg
# maps/val/841.jpg
# maps/val/842.jpg
# maps/val/393.jpg
# maps/val/394.jpg
# maps/val/395.jpg
# maps/val/396.jpg
# maps/val/397.jpg
# maps/val/398.jpg
# maps/val/399.jpg
# maps/val/4.jpg
# maps/val/40.jpg
# maps/val/400.jpg
# maps/val/401.jpg
# maps/val/402.jpg
# maps/val/403.jpg
# maps/val/404.jpg
# maps/val/405.jpg
# maps/val/406.jpg
# maps/val/407.jpg
# maps/val/408.jpg
# maps/val/409.jpg
# maps/val/41.jpg
# maps/val/410.jpg
# maps/val/411.jpg
# maps/val/735.jpg
# maps/val/736.jpg
# maps/val/737.jpg
# maps/val/738.jpg
# maps/val/739.jpg
# maps/val/74.jpg
# maps/val/740.jpg
# maps/val/741.jpg
# maps/val/742.jpg
# maps/val/743.jpg
# maps/val/744.jpg
# maps/val/745.jpg
# maps/val/746.jpg
# maps/val/747.jpg
# maps/val/748.jpg
# maps/val/749.jpg
# maps/val/75.jpg
# maps/val/750.jpg
# maps/val/751.jpg
# maps/val/752.jpg
# maps/val/753.jpg
# maps/val/754.jpg
# maps/val/755.jpg
# maps/val/469.jpg
# maps/val/47.jpg
# maps/val/470.jpg
# maps/val/471.jpg
# maps/val/472.jpg
# maps/val/473.jpg
# maps/val/474.jpg
# maps/val/475.jpg
# maps/val/476.jpg
# maps/val/477.jpg
# maps/val/478.jpg
# maps/val/479.jpg
# maps/val/48.jpg
# maps/val/480.jpg
# maps/val/481.jpg
# maps/val/482.jpg
# maps/val/483.jpg
# maps/val/484.jpg
# maps/val/485.jpg
# maps/val/486.jpg
# maps/val/487.jpg
# maps/val/488.jpg
# maps/val/51.jpg
# maps/val/510.jpg
# maps/val/511.jpg
# maps/val/512.jpg
# maps/val/513.jpg
# maps/val/514.jpg
# maps/val/515.jpg
# maps/val/516.jpg
# maps/val/517.jpg
# maps/val/518.jpg
# maps/val/519.jpg
# maps/val/52.jpg
# maps/val/520.jpg
# maps/val/521.jpg
# maps/val/522.jpg
# maps/val/523.jpg
# maps/val/524.jpg
# maps/val/525.jpg
# maps/val/526.jpg
# maps/val/527.jpg
# maps/val/528.jpg
# maps/val/529.jpg
# maps/val/216.jpg
# maps/val/217.jpg
# maps/val/218.jpg
# maps/val/219.jpg
# maps/val/22.jpg
# maps/val/220.jpg
# maps/val/221.jpg
# maps/val/222.jpg
# maps/val/223.jpg
# maps/val/224.jpg
# maps/val/225.jpg
# maps/val/226.jpg
# maps/val/227.jpg
# maps/val/228.jpg
# maps/val/229.jpg
# maps/val/23.jpg
# maps/val/230.jpg
# maps/val/231.jpg
# maps/val/232.jpg
# maps/val/233.jpg
# maps/val/234.jpg
# maps/val/1017.jpg
# maps/val/1018.jpg
# maps/val/1019.jpg
# maps/val/102.jpg
# maps/val/1020.jpg
# maps/val/1021.jpg
# maps/val/1022.jpg
# maps/val/1023.jpg
# maps/val/1024.jpg
# maps/val/1025.jpg
# maps/val/1026.jpg
# maps/val/1027.jpg
# maps/val/1028.jpg
# maps/val/1029.jpg
# maps/val/103.jpg
# maps/val/1030.jpg
# maps/val/1031.jpg
# maps/val/1032.jpg
# maps/val/1033.jpg
# maps/val/1034.jpg
# maps/val/53.jpg
# maps/val/562.jpg
# maps/val/59.jpg
# maps/val/619.jpg
# maps/val/648.jpg
# maps/val/681.jpg
# maps/val/712.jpg
# maps/val/734.jpg
# maps/val/756.jpg
# maps/val/78.jpg
# maps/val/80.jpg
# maps/val/820.jpg
# maps/val/843.jpg
# maps/val/877.jpg
# maps/val/910.jpg
# maps/val/932.jpg
# maps/val/953.jpg
# maps/val/979.jpg

# %%
# load, split and scale the maps dataset ready for training
from os import listdir
from numpy import asarray
from numpy import vstack
from keras.preprocessing.image import img_to_array
from keras.preprocessing.image import load_img
from numpy import savez_compressed

# load all images in a directory into memory
def load_images(path, size=(256,512)):
	src_list, tar_list = list(), list()
	# enumerate filenames in directory, assume all are images
	for filename in listdir(path):
		# load and resize the image
		pixels = load_img(path + filename, target_size=size)
		# convert to numpy array
		pixels = img_to_array(pixels)
		# split into satellite and map
		sat_img, map_img = pixels[:, :256], pixels[:, 256:]
		src_list.append(sat_img)
		tar_list.append(map_img)
	return [asarray(src_list), asarray(tar_list)]

# dataset path
path = 'maps/train/'
# load dataset
[src_images, tar_images] = load_images(path)
print('Loaded: ', src_images.shape, tar_images.shape)
# save as compressed numpy array
filename = 'maps_256.npz'
savez_compressed(filename, src_images, tar_images)
print('Saved dataset: ', filename)
# Out:
# Using TensorFlow backend.
# Loaded:  (1096, 256, 256, 3) (1096, 256, 256, 3)
# Saved dataset:  maps_256.npz

# %%
# load the prepared dataset
from numpy import load
from matplotlib import pyplot
# load the face dataset
data = load('maps_256.npz')
src_images, tar_images = data['arr_0'], data['arr_1']
print('Loaded: ', src_images.shape, tar_images.shape)
# plot source images
n_samples = 3
for i in range(n_samples):
	pyplot.subplot(2, n_samples, 1 + i)
	pyplot.axis('off')
	pyplot.imshow(src_images[i].astype('uint8'))
# plot target image
for i in range(n_samples):
	pyplot.subplot(2, n_samples, 1 + n_samples + i)
	pyplot.axis('off')
	pyplot.imshow(tar_images[i].astype('uint8'))
pyplot.show()
# Out:
# Loaded:  (1096, 256, 256, 3) (1096, 256, 256, 3)

# %%
# example of pix2pix gan for satellite to map image-to-image translation
from numpy import load
from numpy import zeros
from numpy import ones
from numpy.random import randint
from keras.optimizers import Adam
from keras.initializers import RandomNormal
from keras.models import Model
from keras.models import Input
from keras.layers import Conv2D
from keras.layers import Conv2DTranspose
from keras.layers import LeakyReLU
from keras.layers import Activation
from keras.layers import Concatenate
from keras.layers import Dropout
from keras.layers import BatchNormalization
from keras.layers import LeakyReLU
from matplotlib import pyplot

# define the discriminator model
def define_discriminator(image_shape):
	# weight initialization
	init = RandomNormal(stddev=0.02)
	# source image input
	in_src_image = Input(shape=image_shape)
	# target image input
	in_target_image = Input(shape=image_shape)
	# concatenate images channel-wise
	merged = Concatenate()([in_src_image, in_target_image])
	# C64
	d = Conv2D(64, (4,4), strides=(2,2), padding='same', kernel_initializer=init)(merged)
	d = LeakyReLU(alpha=0.2)(d)
	# C128
	d = Conv2D(128, (4,4), strides=(2,2), padding='same', kernel_initializer=init)(d)
	d = BatchNormalization()(d)
	d = LeakyReLU(alpha=0.2)(d)
	# C256
	d = Conv2D(256, (4,4), strides=(2,2), padding='same', kernel_initializer=init)(d)
	d = BatchNormalization()(d)
	d = LeakyReLU(alpha=0.2)(d)
	# C512
	d = Conv2D(512, (4,4), strides=(2,2), padding='same', kernel_initializer=init)(d)
	d = BatchNormalization()(d)
	d = LeakyReLU(alpha=0.2)(d)
	# second last output layer
	d = Conv2D(512, (4,4), padding='same', kernel_initializer=init)(d)
	d = BatchNormalization()(d)
	d = LeakyReLU(alpha=0.2)(d)
	# patch output
	d = Conv2D(1, (4,4), padding='same', kernel_initializer=init)(d)
	patch_out = Activation('sigmoid')(d)
	# define model
	model = Model([in_src_image, in_target_image], patch_out)
	# compile model
	opt = Adam(lr=0.0002, beta_1=0.5)
	model.compile(loss='binary_crossentropy', optimizer=opt, loss_weights=[0.5])
	return model

# define an encoder block
def define_encoder_block(layer_in, n_filters, batchnorm=True):
	# weight initialization
	init = RandomNormal(stddev=0.02)
	# add downsampling layer
	g = Conv2D(n_filters, (4,4), strides=(2,2), padding='same', kernel_initializer=init)(layer_in)
	# conditionally add batch normalization
	if batchnorm:
		g = BatchNormalization()(g, training=True)
	# leaky relu activation
	g = LeakyReLU(alpha=0.2)(g)
	return g

# define a decoder block
def decoder_block(layer_in, skip_in, n_filters, dropout=True):
	# weight initialization
	init = RandomNormal(stddev=0.02)
	# add upsampling layer
	g = Conv2DTranspose(n_filters, (4,4), strides=(2,2), padding='same', kernel_initializer=init)(layer_in)
	# add batch normalization
	g = BatchNormalization()(g, training=True)
	# conditionally add dropout
	if dropout:
		g = Dropout(0.5)(g, training=True)
	# merge with skip connection
	g = Concatenate()([g, skip_in])
	# relu activation
	g = Activation('relu')(g)
	return g

# define the standalone generator model
def define_generator(image_shape=(256,256,3)):
	# weight initialization
	init = RandomNormal(stddev=0.02)
	# image input
	in_image = Input(shape=image_shape)
	# encoder model
	e1 = define_encoder_block(in_image, 64, batchnorm=False)
	e2 = define_encoder_block(e1, 128)
	e3 = define_encoder_block(e2, 256)
	e4 = define_encoder_block(e3, 512)
	e5 = define_encoder_block(e4, 512)
	e6 = define_encoder_block(e5, 512)
	e7 = define_encoder_block(e6, 512)
	# bottleneck, no batch norm and relu
	b = Conv2D(512, (4,4), strides=(2,2), padding='same', kernel_initializer=init)(e7)
	b = Activation('relu')(b)
	# decoder model
	d1 = decoder_block(b, e7, 512)
	d2 = decoder_block(d1, e6, 512)
	d3 = decoder_block(d2, e5, 512)
	d4 = decoder_block(d3, e4, 512, dropout=False)
	d5 = decoder_block(d4, e3, 256, dropout=False)
	d6 = decoder_block(d5, e2, 128, dropout=False)
	d7 = decoder_block(d6, e1, 64, dropout=False)
	# output
	g = Conv2DTranspose(3, (4,4), strides=(2,2), padding='same', kernel_initializer=init)(d7)
	out_image = Activation('tanh')(g)
	# define model
	model = Model(in_image, out_image)
	return model

# define the combined generator and discriminator model, for updating the generator
def define_gan(g_model, d_model, image_shape):
	# make weights in the discriminator not trainable
	d_model.trainable = False
	# define the source image
	in_src = Input(shape=image_shape)
	# connect the source image to the generator input
	gen_out = g_model(in_src)
	# connect the source input and generator output to the discriminator input
	dis_out = d_model([in_src, gen_out])
	# src image as input, generated image and classification output
	model = Model(in_src, [dis_out, gen_out])
	# compile model
	opt = Adam(lr=0.0002, beta_1=0.5)
	model.compile(loss=['binary_crossentropy', 'mae'], optimizer=opt, loss_weights=[1,100])
	return model

# load and prepare training images
def load_real_samples(filename):
	# load compressed arrays
	data = load(filename)
	# unpack arrays
	X1, X2 = data['arr_0'], data['arr_1']
	# scale from [0,255] to [-1,1]
	X1 = (X1 - 127.5) / 127.5
	X2 = (X2 - 127.5) / 127.5
	return [X1, X2]

# select a batch of random samples, returns images and target
def generate_real_samples(dataset, n_samples, patch_shape):
	# unpack dataset
	trainA, trainB = dataset
	# choose random instances
	ix = randint(0, trainA.shape[0], n_samples)
	# retrieve selected images
	X1, X2 = trainA[ix], trainB[ix]
	# generate 'real' class labels (1)
	y = ones((n_samples, patch_shape, patch_shape, 1))
	return [X1, X2], y

# generate a batch of images, returns images and targets
def generate_fake_samples(g_model, samples, patch_shape):
	# generate fake instance
	X = g_model.predict(samples)
	# create 'fake' class labels (0)
	y = zeros((len(X), patch_shape, patch_shape, 1))
	return X, y

# generate samples and save as a plot and save the model
def summarize_performance(step, g_model, dataset, n_samples=3):
	# select a sample of input images
	[X_realA, X_realB], _ = generate_real_samples(dataset, n_samples, 1)
	# generate a batch of fake samples
	X_fakeB, _ = generate_fake_samples(g_model, X_realA, 1)
	# scale all pixels from [-1,1] to [0,1]
	X_realA = (X_realA + 1) / 2.0
	X_realB = (X_realB + 1) / 2.0
	X_fakeB = (X_fakeB + 1) / 2.0
	# plot real source images
	for i in range(n_samples):
		pyplot.subplot(3, n_samples, 1 + i)
		pyplot.axis('off')
		pyplot.imshow(X_realA[i])
	# plot generated target image
	for i in range(n_samples):
		pyplot.subplot(3, n_samples, 1 + n_samples + i)
		pyplot.axis('off')
		pyplot.imshow(X_fakeB[i])
	# plot real target image
	for i in range(n_samples):
		pyplot.subplot(3, n_samples, 1 + n_samples*2 + i)
		pyplot.axis('off')
		pyplot.imshow(X_realB[i])
	# save plot to file
	filename1 = 'plot_%06d.png' % (step+1)
	pyplot.savefig(filename1)
	pyplot.close()
	# save the generator model
	filename2 = 'model_%06d.h5' % (step+1)
	g_model.save(filename2)
	print('>Saved: %s and %s' % (filename1, filename2))

# train pix2pix models
def train(d_model, g_model, gan_model, dataset, n_epochs=100, n_batch=1):
	# determine the output square shape of the discriminator
	n_patch = d_model.output_shape[1]
	# unpack dataset
	trainA, trainB = dataset
	# calculate the number of batches per training epoch
	bat_per_epo = int(len(trainA) / n_batch)
	# calculate the number of training iterations
	n_steps = bat_per_epo * n_epochs
	# manually enumerate epochs
    print(n_steps)
	for i in range(n_steps):
		# select a batch of real samples
		[X_realA, X_realB], y_real = generate_real_samples(dataset, n_batch, n_patch)
		# generate a batch of fake samples
		X_fakeB, y_fake = generate_fake_samples(g_model, X_realA, n_patch)
		# update discriminator for real samples
		d_loss1 = d_model.train_on_batch([X_realA, X_realB], y_real)
		# update discriminator for generated samples
		d_loss2 = d_model.train_on_batch([X_realA, X_fakeB], y_fake)
		# update the generator
		g_loss, _, _ = gan_model.train_on_batch(X_realA, [y_real, X_realB])
		# summarize performance
		print('>%d, d1[%.3f] d2[%.3f] g[%.3f]' % (i+1, d_loss1, d_loss2, g_loss))
		# summarize model performance
		if (i+1) % (bat_per_epo * 10) == 0:
			summarize_performance(i, g_model, dataset)

# load image data
dataset = load_real_samples('maps_256.npz')
print('Loaded', dataset[0].shape, dataset[1].shape)
# define input shape based on the loaded dataset
image_shape = dataset[0].shape[1:]
# define the models
d_model = define_discriminator(image_shape)
g_model = define_generator(image_shape)
# define the composite model
gan_model = define_gan(g_model, d_model, image_shape)
# train model
train(d_model, g_model, gan_model, dataset)
# Out:
#   File "<ipython-input-7-437b0738989d>", line 213
#     print(n_steps)
#                   ^
# IndentationError: unindent does not match any outer indentation level

# %%
train(d_model, g_model, gan_model, dataset,n_epochs=1)
# Out:
# 1096
# /usr/local/lib/python3.6/dist-packages/keras/engine/training.py:490: UserWarning: Discrepancy between trainable weights and collected trainable weights, did you set `model.trainable` without calling `model.compile` after ?
#   'Discrepancy between trainable weights and collected trainable'
# >1, d1[0.000] d2[0.115] g[10.070]
# >2, d1[0.039] d2[0.010] g[12.508]
# >3, d1[0.145] d2[0.051] g[8.951]
# >4, d1[0.008] d2[0.043] g[9.935]
# >5, d1[0.000] d2[0.003] g[15.940]
# >6, d1[0.124] d2[0.210] g[12.309]
# >7, d1[0.001] d2[0.081] g[11.891]
# >8, d1[0.075] d2[0.003] g[12.088]
# >9, d1[0.457] d2[0.299] g[10.376]
# >10, d1[0.000] d2[0.007] g[17.818]
# >11, d1[0.084] d2[0.000] g[11.973]
# >12, d1[0.008] d2[0.010] g[10.270]
# >13, d1[0.030] d2[0.135] g[10.543]
# >14, d1[0.158] d2[0.015] g[10.862]
# >15, d1[0.000] d2[0.000] g[10.999]
# >16, d1[0.000] d2[0.003] g[7.866]
# >17, d1[0.022] d2[0.030] g[9.045]
# >18, d1[0.000] d2[0.038] g[15.485]
# >19, d1[0.001] d2[0.044] g[10.986]
# >20, d1[0.000] d2[0.001] g[15.874]
# >21, d1[0.000] d2[0.315] g[16.603]
# >22, d1[0.151] d2[0.018] g[10.109]
# >23, d1[0.292] d2[0.008] g[11.952]
# >24, d1[0.028] d2[0.201] g[11.699]
# >25, d1[0.007] d2[0.234] g[11.510]
# >26, d1[0.067] d2[0.001] g[14.520]
# >27, d1[0.001] d2[0.001] g[14.951]
# >28, d1[0.001] d2[0.001] g[18.156]
# >29, d1[0.032] d2[0.001] g[15.931]
# >30, d1[0.000] d2[0.001] g[18.537]
# >31, d1[0.057] d2[0.002] g[12.909]
# >32, d1[0.000] d2[0.011] g[14.609]
# >33, d1[0.118] d2[0.049] g[9.507]
# >34, d1[0.002] d2[0.102] g[13.919]
# >35, d1[0.014] d2[0.001] g[21.466]
# >36, d1[0.238] d2[0.148] g[10.513]
# >37, d1[0.083] d2[0.004] g[12.815]
# >38, d1[0.062] d2[0.025] g[10.824]
# >39, d1[0.021] d2[0.001] g[12.939]
# >40, d1[0.000] d2[0.061] g[11.182]
# >41, d1[0.016] d2[0.012] g[10.974]
# >42, d1[0.012] d2[0.033] g[8.773]
# >43, d1[0.001] d2[0.153] g[10.877]
# >44, d1[0.000] d2[0.003] g[16.822]
# >45, d1[0.000] d2[0.003] g[15.899]
# >46, d1[0.148] d2[0.084] g[8.138]
# >47, d1[0.000] d2[0.008] g[12.732]
# >48, d1[0.001] d2[0.005] g[17.566]
# >49, d1[0.001] d2[0.000] g[10.738]
# >50, d1[0.671] d2[0.007] g[10.687]
# >51, d1[0.001] d2[0.656] g[14.002]
# >52, d1[0.004] d2[0.078] g[11.347]
# >53, d1[0.001] d2[0.003] g[14.903]
# >54, d1[1.378] d2[0.018] g[8.081]
# >55, d1[0.003] d2[0.121] g[10.162]
# >56, d1[0.000] d2[1.094] g[16.856]
# >57, d1[0.583] d2[0.002] g[13.427]
# >58, d1[0.622] d2[0.507] g[10.717]
# >59, d1[0.006] d2[0.000] g[15.041]
# >60, d1[0.000] d2[0.001] g[18.541]
# >61, d1[0.197] d2[0.064] g[7.700]
# >62, d1[0.000] d2[0.007] g[15.917]
# >63, d1[0.040] d2[0.014] g[10.025]
# >64, d1[0.006] d2[0.127] g[10.402]
# >65, d1[0.001] d2[0.368] g[13.658]
# >66, d1[0.000] d2[0.004] g[18.802]
# >67, d1[1.511] d2[0.015] g[8.764]
# >68, d1[0.000] d2[0.220] g[12.994]
# >69, d1[0.000] d2[0.024] g[17.233]
# >70, d1[0.107] d2[0.289] g[10.200]
# >71, d1[0.083] d2[0.016] g[10.236]
# >72, d1[0.000] d2[0.006] g[17.667]
# >73, d1[0.014] d2[0.000] g[10.878]
# >74, d1[0.168] d2[0.222] g[9.162]
# >75, d1[0.098] d2[0.027] g[10.365]
# >76, d1[0.067] d2[0.064] g[9.495]
# >77, d1[0.026] d2[0.192] g[9.908]
# >78, d1[0.000] d2[0.002] g[19.474]
# >79, d1[0.575] d2[0.059] g[8.898]
# >80, d1[0.000] d2[0.395] g[14.210]
# >81, d1[0.002] d2[0.002] g[18.141]
# >82, d1[0.000] d2[0.009] g[15.300]
# >83, d1[0.124] d2[0.002] g[15.939]
# >84, d1[0.000] d2[0.010] g[17.933]
# >85, d1[0.000] d2[0.008] g[15.518]
# >86, d1[0.000] d2[0.001] g[17.455]
# >87, d1[0.257] d2[0.018] g[11.349]
# >88, d1[0.000] d2[0.245] g[16.665]
# >89, d1[0.098] d2[0.043] g[11.573]
# >90, d1[0.018] d2[0.064] g[8.876]
# >91, d1[0.027] d2[0.036] g[10.686]
# >92, d1[0.003] d2[0.064] g[10.362]
# >93, d1[0.004] d2[0.004] g[13.789]
# >94, d1[0.000] d2[0.007] g[13.885]
# >95, d1[0.154] d2[0.074] g[9.099]
# >96, d1[0.363] d2[0.299] g[7.973]
# >97, d1[0.001] d2[0.350] g[14.451]
# >98, d1[0.048] d2[0.001] g[16.275]
# >99, d1[0.348] d2[0.036] g[10.148]
# >100, d1[0.002] d2[0.018] g[12.404]
# >101, d1[0.133] d2[0.432] g[11.454]
# >102, d1[0.049] d2[0.008] g[11.675]
# >103, d1[0.128] d2[0.027] g[8.959]
# >104, d1[0.000] d2[0.003] g[18.572]
# >105, d1[0.051] d2[0.068] g[11.200]
# >106, d1[0.182] d2[0.033] g[9.062]
# >107, d1[0.005] d2[0.458] g[13.195]
# >108, d1[0.045] d2[0.001] g[15.467]
# >109, d1[0.000] d2[0.001] g[19.484]
# >110, d1[0.005] d2[0.004] g[12.953]
# >111, d1[0.001] d2[0.001] g[18.271]
# >112, d1[0.171] d2[0.085] g[9.821]
# >113, d1[0.019] d2[0.006] g[11.928]
# >114, d1[0.384] d2[0.050] g[10.015]
# >115, d1[0.106] d2[0.275] g[10.975]
# >116, d1[0.026] d2[0.017] g[12.720]
# >117, d1[0.148] d2[0.260] g[10.948]
# >118, d1[0.023] d2[0.012] g[11.909]
# >119, d1[1.367] d2[0.198] g[10.254]
# >120, d1[0.100] d2[0.023] g[14.825]
# >121, d1[0.000] d2[0.138] g[16.165]
# >122, d1[0.000] d2[0.009] g[14.191]
# >123, d1[0.000] d2[0.009] g[13.829]
# >124, d1[0.032] d2[0.480] g[12.315]
# >125, d1[0.927] d2[0.582] g[13.747]
# >126, d1[0.000] d2[0.001] g[23.359]
# >127, d1[0.553] d2[0.029] g[7.321]
# >128, d1[0.090] d2[0.092] g[9.156]
# >129, d1[0.000] d2[0.035] g[15.439]
# >130, d1[0.014] d2[0.612] g[12.781]
# >131, d1[0.213] d2[0.049] g[9.003]
# >132, d1[0.289] d2[0.034] g[8.393]
# >133, d1[0.222] d2[0.031] g[10.878]
# >134, d1[0.152] d2[0.178] g[9.266]
# >135, d1[0.005] d2[0.078] g[10.837]
# >136, d1[0.008] d2[0.037] g[10.428]
# >137, d1[0.000] d2[0.017] g[17.799]
# >138, d1[0.010] d2[0.024] g[10.223]
# >139, d1[0.001] d2[0.029] g[12.662]
# >140, d1[0.023] d2[0.064] g[9.535]
# >141, d1[0.000] d2[0.012] g[13.239]
# >142, d1[1.606] d2[0.106] g[7.736]
# >143, d1[0.030] d2[0.203] g[9.059]
# >144, d1[0.038] d2[0.422] g[10.766]
# >145, d1[0.000] d2[0.005] g[15.474]
# >146, d1[0.605] d2[0.395] g[9.404]
# >147, d1[0.025] d2[0.043] g[11.162]
# >148, d1[0.111] d2[0.064] g[9.360]
# >149, d1[0.039] d2[0.022] g[11.921]
# >150, d1[0.000] d2[0.076] g[15.130]
# >151, d1[0.148] d2[0.289] g[9.881]
# >152, d1[0.491] d2[0.242] g[7.714]
# >153, d1[0.001] d2[0.001] g[9.829]
# >154, d1[0.605] d2[0.018] g[11.218]
# >155, d1[0.000] d2[0.161] g[11.699]
# >156, d1[0.000] d2[0.593] g[20.345]
# >157, d1[0.000] d2[0.003] g[13.918]
# >158, d1[0.022] d2[0.001] g[16.105]
# >159, d1[0.448] d2[0.017] g[9.804]
# >160, d1[0.000] d2[0.005] g[16.267]
# >161, d1[0.011] d2[0.018] g[11.918]
# >162, d1[0.016] d2[0.014] g[14.938]
# >163, d1[0.003] d2[0.584] g[13.843]
# >164, d1[0.152] d2[0.006] g[9.473]
# >165, d1[0.562] d2[0.101] g[10.125]
# >166, d1[0.000] d2[0.053] g[10.624]
# >167, d1[0.002] d2[0.060] g[7.468]
# >168, d1[0.000] d2[0.002] g[14.173]
# >169, d1[0.001] d2[0.010] g[11.638]
# >170, d1[0.087] d2[0.052] g[10.645]
# >171, d1[0.000] d2[0.009] g[14.044]
# >172, d1[0.000] d2[1.094] g[19.539]
# >173, d1[0.964] d2[0.133] g[8.550]
# >174, d1[0.001] d2[0.002] g[18.608]
# >175, d1[0.057] d2[0.001] g[14.298]
# >176, d1[0.000] d2[0.007] g[18.014]
# >177, d1[0.002] d2[0.017] g[13.468]
# >178, d1[0.216] d2[0.200] g[10.640]
# >179, d1[0.000] d2[0.001] g[16.797]
# >180, d1[0.921] d2[0.284] g[10.984]
# >181, d1[0.323] d2[0.171] g[8.334]
# >182, d1[0.100] d2[0.315] g[9.846]
# >183, d1[0.058] d2[0.038] g[12.087]
# >184, d1[0.046] d2[0.018] g[8.067]
# >185, d1[0.378] d2[0.083] g[8.827]
# >186, d1[0.007] d2[0.328] g[10.716]
# >187, d1[0.035] d2[0.010] g[13.454]
# >188, d1[0.000] d2[0.041] g[15.346]
# >189, d1[0.016] d2[0.048] g[9.779]
# >190, d1[0.001] d2[0.001] g[12.677]
# >191, d1[0.000] d2[0.002] g[18.600]
# >192, d1[0.030] d2[0.156] g[11.255]
# >193, d1[1.833] d2[0.040] g[7.676]
# >194, d1[0.000] d2[0.337] g[15.436]
# >195, d1[0.000] d2[0.027] g[15.963]
# >196, d1[0.359] d2[0.149] g[8.158]
# >197, d1[0.000] d2[0.201] g[16.383]
# >198, d1[0.000] d2[0.012] g[14.120]
# >199, d1[0.070] d2[0.076] g[9.086]
# >200, d1[0.000] d2[0.003] g[18.596]
# >201, d1[0.236] d2[0.062] g[9.538]
# >202, d1[0.160] d2[0.061] g[8.990]
# >203, d1[0.014] d2[0.021] g[10.068]
# >204, d1[0.000] d2[0.006] g[14.999]
# >205, d1[0.000] d2[0.022] g[15.425]
# >206, d1[0.026] d2[0.135] g[10.441]
# >207, d1[0.000] d2[0.009] g[14.650]
# >208, d1[0.313] d2[0.060] g[9.373]
# >209, d1[0.049] d2[0.138] g[9.865]
# >210, d1[0.000] d2[0.202] g[7.973]
# >211, d1[0.075] d2[0.013] g[9.934]
# >212, d1[0.049] d2[0.038] g[9.563]
# >213, d1[0.035] d2[0.020] g[12.313]
# >214, d1[0.000] d2[0.012] g[14.804]
# >215, d1[0.000] d2[0.022] g[14.714]
# >216, d1[0.018] d2[0.022] g[11.050]
# >217, d1[0.078] d2[0.060] g[12.922]
# >218, d1[0.000] d2[0.024] g[11.184]
# >219, d1[0.012] d2[0.079] g[11.569]
# >220, d1[0.000] d2[1.075] g[18.326]
# >221, d1[0.031] d2[0.009] g[8.360]
# >222, d1[0.322] d2[0.183] g[7.528]
# >223, d1[4.033] d2[0.133] g[9.982]
# >224, d1[0.000] d2[0.004] g[16.294]
# >225, d1[0.585] d2[0.128] g[9.240]
# >226, d1[0.001] d2[0.045] g[18.064]
# >227, d1[0.012] d2[0.545] g[10.418]
# >228, d1[0.000] d2[0.001] g[13.611]
# >229, d1[0.326] d2[0.021] g[9.374]
# >230, d1[0.144] d2[0.032] g[8.941]
# >231, d1[0.032] d2[0.034] g[13.057]
# >232, d1[0.000] d2[0.018] g[11.621]
# >233, d1[0.000] d2[0.003] g[14.522]
# >234, d1[0.069] d2[0.021] g[11.426]
# >235, d1[0.008] d2[0.064] g[10.690]
# >236, d1[0.000] d2[0.069] g[12.354]
# >237, d1[0.073] d2[0.131] g[11.871]
# >238, d1[0.003] d2[0.422] g[12.565]
# >239, d1[0.000] d2[0.001] g[22.852]
# >240, d1[0.004] d2[0.000] g[17.880]
# >241, d1[1.355] d2[0.069] g[9.220]
# >242, d1[0.120] d2[0.012] g[12.573]
# >243, d1[0.000] d2[1.150] g[13.186]
# >244, d1[0.000] d2[0.001] g[18.430]
# >245, d1[1.107] d2[0.344] g[7.865]
# >246, d1[0.322] d2[0.020] g[9.733]
# >247, d1[0.000] d2[0.053] g[14.751]
# >248, d1[0.855] d2[0.084] g[8.374]
# >249, d1[0.000] d2[1.061] g[11.132]
# >250, d1[0.018] d2[0.079] g[8.965]
# >251, d1[0.001] d2[0.032] g[15.806]
# >252, d1[0.009] d2[0.013] g[11.538]
# >253, d1[0.001] d2[0.277] g[14.774]
# >254, d1[0.000] d2[0.002] g[17.088]
# >255, d1[0.607] d2[0.294] g[9.991]
# >256, d1[0.171] d2[0.023] g[10.319]
# >257, d1[0.672] d2[0.306] g[7.589]
# >258, d1[0.000] d2[0.423] g[15.678]
# >259, d1[0.062] d2[0.067] g[10.223]
# >260, d1[0.001] d2[0.008] g[12.773]
# >261, d1[0.237] d2[0.045] g[9.887]
# >262, d1[0.003] d2[0.464] g[14.795]
# >263, d1[2.054] d2[0.045] g[7.374]
# >264, d1[0.207] d2[0.026] g[12.548]
# >265, d1[0.024] d2[0.355] g[10.503]
# >266, d1[0.003] d2[0.035] g[13.040]
# >267, d1[0.291] d2[0.020] g[10.149]
# >268, d1[0.076] d2[0.210] g[8.290]
# >269, d1[0.281] d2[0.060] g[9.157]
# >270, d1[0.761] d2[0.002] g[8.935]
# >271, d1[0.004] d2[0.002] g[7.996]
# >272, d1[0.001] d2[0.465] g[10.679]
# >273, d1[0.084] d2[0.060] g[8.908]
# >274, d1[0.277] d2[0.103] g[10.347]
# >275, d1[0.000] d2[0.054] g[14.758]
# >276, d1[0.000] d2[0.028] g[14.640]
# >277, d1[0.009] d2[0.026] g[8.283]
# >278, d1[0.000] d2[0.418] g[12.722]
# >279, d1[0.329] d2[0.036] g[10.202]
# >280, d1[0.029] d2[0.075] g[9.542]
# >281, d1[0.384] d2[0.252] g[9.534]
# >282, d1[0.016] d2[0.079] g[9.427]
# >283, d1[0.007] d2[0.113] g[13.377]
# >284, d1[0.003] d2[0.026] g[11.751]
# >285, d1[0.113] d2[0.236] g[9.904]
# >286, d1[0.177] d2[0.012] g[12.414]
# >287, d1[0.324] d2[0.085] g[8.116]
# >288, d1[0.050] d2[0.014] g[12.797]
# >289, d1[0.000] d2[0.080] g[10.963]
# >290, d1[0.016] d2[0.076] g[9.377]
# >291, d1[0.025] d2[0.109] g[10.309]
# >292, d1[0.139] d2[0.101] g[9.677]
# >293, d1[0.028] d2[0.259] g[9.824]
# >294, d1[0.003] d2[0.131] g[11.703]
# >295, d1[0.026] d2[0.006] g[15.472]
# >296, d1[0.765] d2[0.223] g[8.773]
# >297, d1[0.000] d2[0.003] g[16.609]
# >298, d1[0.017] d2[0.056] g[9.649]
# >299, d1[0.261] d2[0.004] g[11.047]
# >300, d1[0.076] d2[0.087] g[12.229]
# >301, d1[0.000] d2[0.128] g[12.787]
# >302, d1[0.409] d2[0.249] g[9.143]
# >303, d1[0.005] d2[0.010] g[7.975]
# >304, d1[0.084] d2[0.168] g[9.694]
# >305, d1[0.000] d2[0.063] g[14.573]
# >306, d1[0.147] d2[0.017] g[10.807]
# >307, d1[0.020] d2[0.068] g[9.816]
# >308, d1[0.000] d2[0.001] g[15.805]
# >309, d1[0.037] d2[0.037] g[10.559]
# >310, d1[0.996] d2[0.020] g[10.010]
# >311, d1[0.015] d2[0.164] g[9.773]
# >312, d1[0.002] d2[0.372] g[12.161]
# >313, d1[0.002] d2[0.083] g[12.842]
# >314, d1[0.222] d2[0.012] g[11.050]
# >315, d1[0.066] d2[0.090] g[8.671]
# >316, d1[0.000] d2[0.013] g[11.717]
# >317, d1[0.006] d2[0.079] g[12.847]
# >318, d1[0.091] d2[0.026] g[10.536]
# >319, d1[0.000] d2[0.007] g[15.524]
# >320, d1[0.019] d2[0.010] g[11.193]
# >321, d1[0.000] d2[0.023] g[14.567]
# >322, d1[0.094] d2[0.030] g[11.018]
# >323, d1[0.000] d2[0.010] g[14.362]
# >324, d1[0.116] d2[0.221] g[11.212]
# >325, d1[0.001] d2[0.006] g[17.776]
# >326, d1[0.003] d2[0.177] g[8.895]
# >327, d1[0.252] d2[0.020] g[11.054]
# >328, d1[0.078] d2[0.029] g[9.231]
# >329, d1[0.098] d2[0.103] g[9.770]
# >330, d1[0.015] d2[0.234] g[14.970]
# >331, d1[0.192] d2[0.078] g[9.801]
# >332, d1[0.045] d2[0.010] g[11.200]
# >333, d1[0.000] d2[0.049] g[12.891]
# >334, d1[0.000] d2[0.035] g[8.672]
# >335, d1[0.007] d2[0.010] g[10.645]
# >336, d1[0.000] d2[0.017] g[16.333]
# >337, d1[0.011] d2[0.467] g[13.351]
# >338, d1[1.728] d2[0.024] g[8.007]
# >339, d1[0.076] d2[0.015] g[12.680]
# >340, d1[0.022] d2[0.898] g[13.786]
# >341, d1[0.012] d2[0.024] g[11.040]
# >342, d1[0.456] d2[0.246] g[9.567]
# >343, d1[0.442] d2[0.021] g[10.465]
# >344, d1[0.007] d2[0.126] g[10.207]
# >345, d1[0.262] d2[0.171] g[10.412]
# >346, d1[0.012] d2[0.049] g[10.409]
# >347, d1[0.043] d2[0.013] g[10.027]
# >348, d1[0.047] d2[0.126] g[9.400]
# >349, d1[0.078] d2[0.010] g[10.449]
# >350, d1[0.049] d2[0.020] g[10.223]
# >351, d1[0.020] d2[0.250] g[10.518]
# >352, d1[0.000] d2[0.005] g[16.636]
# >353, d1[0.151] d2[0.020] g[10.181]
# >354, d1[0.024] d2[0.045] g[9.526]
# >355, d1[0.021] d2[0.099] g[8.729]
# >356, d1[0.085] d2[0.006] g[11.515]
# >357, d1[0.076] d2[0.008] g[14.174]
# >358, d1[0.196] d2[0.100] g[8.131]
# >359, d1[0.000] d2[0.041] g[14.213]
# >360, d1[0.000] d2[0.017] g[19.650]
# >361, d1[0.010] d2[0.112] g[6.700]
# >362, d1[0.005] d2[0.251] g[14.045]
# >363, d1[0.068] d2[0.020] g[10.887]
# >364, d1[0.568] d2[0.034] g[9.709]
# >365, d1[0.000] d2[0.076] g[18.353]
# >366, d1[0.027] d2[0.099] g[13.850]
# >367, d1[0.019] d2[0.032] g[8.242]
# >368, d1[0.000] d2[0.155] g[13.192]
# >369, d1[0.001] d2[0.004] g[15.484]
# >370, d1[0.000] d2[0.001] g[14.638]
# >371, d1[0.435] d2[0.040] g[9.258]
# >372, d1[0.056] d2[0.020] g[8.912]
# >373, d1[0.001] d2[1.143] g[13.740]
# >374, d1[0.018] d2[0.002] g[15.208]
# >375, d1[0.846] d2[0.028] g[12.567]
# >376, d1[0.215] d2[0.086] g[8.537]
# >377, d1[0.005] d2[0.260] g[10.098]
# >378, d1[0.021] d2[0.002] g[16.333]
# >379, d1[0.181] d2[0.009] g[10.452]
# >380, d1[0.000] d2[0.061] g[12.587]
# >381, d1[0.000] d2[0.738] g[15.779]
# >382, d1[0.016] d2[0.023] g[10.743]
# >383, d1[0.264] d2[0.028] g[8.673]
# >384, d1[0.088] d2[0.004] g[13.504]
# >385, d1[0.592] d2[1.156] g[14.971]
# >386, d1[0.209] d2[0.105] g[8.036]
# >387, d1[0.010] d2[0.013] g[12.375]
# >388, d1[0.162] d2[0.062] g[8.986]
# >389, d1[0.000] d2[0.188] g[16.242]
# >390, d1[0.241] d2[0.013] g[13.994]
# >391, d1[0.021] d2[0.463] g[12.318]
# >392, d1[0.018] d2[0.135] g[9.009]
# >393, d1[0.128] d2[0.154] g[8.218]
# >394, d1[1.046] d2[0.018] g[10.180]
# >395, d1[0.031] d2[0.300] g[8.768]
# >396, d1[0.335] d2[0.039] g[9.636]
# >397, d1[0.420] d2[0.010] g[9.131]
# >398, d1[0.001] d2[0.002] g[8.161]
# >399, d1[0.003] d2[0.800] g[13.743]
# >400, d1[0.144] d2[0.017] g[10.281]
# >401, d1[0.001] d2[0.004] g[16.531]
# >402, d1[0.000] d2[0.016] g[12.031]
# >403, d1[0.003] d2[0.006] g[8.242]
# >404, d1[0.095] d2[0.065] g[8.940]
# >405, d1[0.000] d2[0.006] g[18.779]
# >406, d1[0.031] d2[0.151] g[10.418]
# >407, d1[0.010] d2[0.079] g[10.582]
# >408, d1[0.000] d2[0.001] g[20.363]
# >409, d1[0.025] d2[0.028] g[8.503]
# >410, d1[0.340] d2[0.084] g[8.330]
# >411, d1[0.002] d2[0.367] g[12.192]
# >412, d1[0.260] d2[0.006] g[9.905]
# >413, d1[0.021] d2[0.001] g[13.001]
# >414, d1[0.004] d2[0.180] g[7.887]
# >415, d1[0.132] d2[0.007] g[12.038]
# >416, d1[0.005] d2[0.012] g[7.021]
# >417, d1[0.277] d2[0.097] g[8.833]
# >418, d1[0.007] d2[0.028] g[10.988]
# >419, d1[0.078] d2[0.003] g[13.815]
# >420, d1[0.035] d2[0.051] g[9.070]
# >421, d1[0.000] d2[0.072] g[12.226]
# >422, d1[0.012] d2[0.011] g[11.188]
# >423, d1[0.000] d2[0.033] g[11.665]
# >424, d1[0.004] d2[0.051] g[12.176]
# >425, d1[0.000] d2[0.004] g[16.079]
# >426, d1[0.018] d2[0.008] g[12.766]
# >427, d1[0.103] d2[0.228] g[9.606]
# >428, d1[0.000] d2[0.094] g[15.540]
# >429, d1[0.014] d2[0.011] g[10.663]
# >430, d1[0.240] d2[0.014] g[12.050]
# >431, d1[0.085] d2[0.022] g[9.847]
# >432, d1[0.000] d2[0.009] g[14.029]
# >433, d1[0.003] d2[0.073] g[8.911]
# >434, d1[0.023] d2[0.080] g[8.927]
# >435, d1[0.000] d2[0.056] g[18.162]
# >436, d1[0.271] d2[0.070] g[8.600]
# >437, d1[0.020] d2[0.192] g[9.965]
# >438, d1[0.017] d2[0.070] g[8.520]
# >439, d1[0.000] d2[0.003] g[18.484]
# >440, d1[0.011] d2[0.013] g[14.116]
# >441, d1[0.002] d2[0.000] g[13.670]
# >442, d1[0.056] d2[0.008] g[9.861]
# >443, d1[0.221] d2[0.167] g[8.991]
# >444, d1[0.005] d2[0.024] g[9.832]
# >445, d1[0.001] d2[0.005] g[15.321]
# >446, d1[0.000] d2[0.029] g[15.817]
# >447, d1[0.002] d2[0.009] g[15.376]
# >448, d1[0.000] d2[0.023] g[17.662]
# >449, d1[0.235] d2[0.008] g[12.823]
# >450, d1[0.016] d2[0.164] g[11.944]
# >451, d1[0.258] d2[0.088] g[8.711]
# >452, d1[0.012] d2[0.011] g[10.577]
# >453, d1[0.004] d2[0.060] g[12.606]
# >454, d1[0.000] d2[0.005] g[13.668]
# >455, d1[0.000] d2[0.024] g[15.004]
# >456, d1[0.095] d2[0.066] g[9.526]
# >457, d1[0.020] d2[0.013] g[12.078]
# >458, d1[0.082] d2[0.032] g[9.989]
# >459, d1[0.019] d2[0.046] g[10.679]
# >460, d1[0.030] d2[0.128] g[8.444]
# >461, d1[0.000] d2[0.032] g[16.131]
# >462, d1[0.000] d2[0.004] g[15.994]
# >463, d1[0.002] d2[0.009] g[12.820]
# >464, d1[0.005] d2[1.361] g[14.079]
# >465, d1[0.000] d2[0.000] g[24.610]
# >466, d1[0.982] d2[0.108] g[8.045]
# >467, d1[0.001] d2[0.013] g[13.002]
# >468, d1[0.005] d2[0.165] g[8.560]
# >469, d1[0.407] d2[0.006] g[12.918]
# >470, d1[0.002] d2[0.119] g[16.298]
# >471, d1[0.008] d2[0.254] g[11.567]
# >472, d1[0.000] d2[0.000] g[25.304]
# >473, d1[0.002] d2[0.000] g[19.431]
# >474, d1[0.211] d2[0.023] g[8.947]
# >475, d1[0.601] d2[0.170] g[9.397]
# >476, d1[0.031] d2[0.146] g[7.126]
# >477, d1[0.014] d2[0.168] g[10.996]
# >478, d1[0.000] d2[0.003] g[14.688]
# >479, d1[0.343] d2[0.204] g[9.088]
# >480, d1[0.279] d2[0.051] g[8.431]
# >481, d1[0.000] d2[0.011] g[14.591]
# >482, d1[0.001] d2[0.493] g[13.140]
# >483, d1[0.130] d2[0.011] g[14.454]
# >484, d1[0.000] d2[0.011] g[18.498]
# >485, d1[0.013] d2[0.000] g[12.772]
# >486, d1[0.000] d2[0.000] g[16.152]
# >487, d1[0.740] d2[0.506] g[12.184]
# >488, d1[0.066] d2[0.004] g[11.663]
# >489, d1[0.000] d2[0.019] g[14.196]
# >490, d1[0.206] d2[0.361] g[10.942]
# >491, d1[0.055] d2[0.003] g[13.106]
# >492, d1[0.000] d2[0.001] g[17.124]
# >493, d1[1.037] d2[0.366] g[9.307]
# >494, d1[0.095] d2[0.021] g[10.254]
# >495, d1[0.019] d2[0.033] g[13.360]
# >496, d1[0.012] d2[0.065] g[12.272]
# >497, d1[0.000] d2[0.003] g[16.809]
# >498, d1[0.000] d2[0.012] g[15.810]
# >499, d1[0.003] d2[0.016] g[14.738]
# >500, d1[0.002] d2[0.018] g[11.648]
# >501, d1[0.014] d2[0.161] g[8.873]
# >502, d1[0.026] d2[0.007] g[9.404]
# >503, d1[0.327] d2[0.073] g[9.851]
# >504, d1[0.101] d2[0.149] g[8.878]
# >505, d1[0.034] d2[0.149] g[10.103]
# >506, d1[0.258] d2[0.126] g[9.138]
# >507, d1[0.061] d2[0.365] g[11.536]
# >508, d1[0.000] d2[0.010] g[12.222]
# >509, d1[0.123] d2[0.163] g[9.304]
# >510, d1[0.223] d2[0.057] g[10.211]
# >511, d1[0.002] d2[0.002] g[14.364]
# >512, d1[0.006] d2[0.024] g[11.054]
# >513, d1[0.000] d2[0.009] g[19.625]
# >514, d1[0.000] d2[0.022] g[14.611]
# >515, d1[0.018] d2[0.128] g[7.664]
# >516, d1[0.000] d2[0.002] g[23.320]
# >517, d1[0.000] d2[0.024] g[14.288]
# >518, d1[0.071] d2[0.015] g[11.346]
# >519, d1[0.431] d2[0.000] g[12.120]
# >520, d1[0.029] d2[0.002] g[11.730]
# >521, d1[0.009] d2[0.078] g[11.623]
# >522, d1[0.000] d2[0.057] g[14.237]
# >523, d1[0.000] d2[0.028] g[13.253]
# >524, d1[0.600] d2[0.069] g[8.567]
# >525, d1[0.011] d2[0.001] g[16.816]
# >526, d1[0.024] d2[0.856] g[14.393]
# >527, d1[0.000] d2[0.001] g[20.536]
# >528, d1[0.001] d2[0.000] g[21.841]
# >529, d1[1.929] d2[1.183] g[11.576]
# >530, d1[0.007] d2[0.002] g[15.003]
# >531, d1[0.000] d2[0.069] g[21.625]
# >532, d1[1.493] d2[0.044] g[9.031]
# >533, d1[0.117] d2[0.261] g[8.906]
# >534, d1[0.549] d2[0.407] g[8.028]
# >535, d1[0.122] d2[0.032] g[10.563]
# >536, d1[0.105] d2[0.013] g[13.248]
# >537, d1[0.035] d2[0.213] g[9.660]
# >538, d1[0.523] d2[0.265] g[8.186]
# >539, d1[0.003] d2[0.038] g[8.234]
# >540, d1[0.000] d2[0.029] g[15.585]
# >541, d1[0.236] d2[0.020] g[9.316]
# >542, d1[0.038] d2[0.270] g[10.563]
# >543, d1[0.000] d2[0.117] g[12.734]
# >544, d1[0.057] d2[0.024] g[9.719]
# >545, d1[0.234] d2[0.086] g[8.677]
# >546, d1[0.000] d2[0.136] g[15.982]
# >547, d1[0.017] d2[0.007] g[13.388]
# >548, d1[0.120] d2[0.144] g[9.770]
# >549, d1[0.095] d2[0.075] g[8.243]
# >550, d1[0.000] d2[0.001] g[9.408]
# >551, d1[0.010] d2[0.086] g[8.976]
# >552, d1[0.497] d2[0.114] g[7.957]
# >553, d1[0.124] d2[0.302] g[9.261]
# >554, d1[0.002] d2[0.081] g[9.803]
# >555, d1[0.000] d2[0.023] g[14.772]
# >556, d1[0.446] d2[0.059] g[10.030]
# >557, d1[0.062] d2[0.073] g[8.416]
# >558, d1[0.000] d2[0.106] g[14.749]
# >559, d1[0.000] d2[0.231] g[12.227]
# >560, d1[0.299] d2[0.109] g[9.152]
# >561, d1[0.093] d2[0.013] g[10.779]
# >562, d1[0.025] d2[0.028] g[13.885]
# >563, d1[0.051] d2[0.014] g[9.500]
# >564, d1[0.024] d2[0.017] g[11.727]
# >565, d1[0.013] d2[0.152] g[10.621]
# >566, d1[0.000] d2[0.022] g[14.082]
# >567, d1[0.112] d2[0.019] g[8.799]
# >568, d1[0.012] d2[0.082] g[10.994]
# >569, d1[0.000] d2[0.022] g[12.975]
# >570, d1[0.360] d2[0.179] g[8.626]
# >571, d1[0.000] d2[0.263] g[16.897]
# >572, d1[0.038] d2[0.015] g[8.871]
# >573, d1[0.110] d2[0.007] g[10.395]
# >574, d1[0.000] d2[0.013] g[15.704]
# >575, d1[0.013] d2[0.256] g[10.970]
# >576, d1[0.146] d2[0.036] g[8.511]
# >577, d1[0.500] d2[0.354] g[10.326]
# >578, d1[0.000] d2[0.016] g[14.894]
# >579, d1[0.005] d2[0.392] g[9.542]
# >580, d1[0.101] d2[0.013] g[9.975]
# >581, d1[0.217] d2[0.004] g[12.971]
# >582, d1[0.129] d2[0.317] g[9.126]
# >583, d1[0.073] d2[0.120] g[6.566]
# >584, d1[0.207] d2[0.153] g[9.613]
# >585, d1[0.178] d2[0.015] g[9.280]
# >586, d1[0.006] d2[0.201] g[11.295]
# >587, d1[0.212] d2[0.056] g[8.946]
# >588, d1[0.000] d2[0.007] g[14.910]
# >589, d1[0.000] d2[0.012] g[15.471]
# >590, d1[0.032] d2[0.010] g[10.685]
# >591, d1[0.141] d2[0.141] g[8.994]
# >592, d1[0.062] d2[0.095] g[8.866]
# >593, d1[0.000] d2[0.024] g[9.633]
# >594, d1[0.005] d2[0.077] g[9.354]
# >595, d1[0.034] d2[0.097] g[9.766]
# >596, d1[0.315] d2[0.032] g[9.813]
# >597, d1[0.000] d2[0.017] g[13.573]
# >598, d1[0.000] d2[0.018] g[16.499]
# >599, d1[0.002] d2[0.055] g[11.794]
# >600, d1[0.050] d2[0.015] g[11.549]
# >601, d1[0.174] d2[0.009] g[10.148]
# >602, d1[0.002] d2[0.117] g[12.414]
# >603, d1[0.041] d2[0.063] g[11.569]
# >604, d1[0.020] d2[0.010] g[10.377]
# >605, d1[0.334] d2[0.134] g[8.788]
# >606, d1[0.022] d2[0.189] g[11.606]
# >607, d1[0.034] d2[0.071] g[9.116]
# >608, d1[0.000] d2[0.001] g[17.349]
# >609, d1[0.002] d2[0.047] g[11.060]
# >610, d1[0.000] d2[0.003] g[19.415]
# >611, d1[0.000] d2[0.025] g[22.508]
# >612, d1[0.066] d2[0.101] g[9.391]
# >613, d1[0.014] d2[0.009] g[11.991]
# >614, d1[0.018] d2[0.036] g[12.495]
# >615, d1[0.068] d2[0.071] g[11.855]
# >616, d1[0.036] d2[0.017] g[7.044]
# >617, d1[0.391] d2[0.114] g[9.765]
# >618, d1[0.000] d2[0.404] g[14.762]
# >619, d1[0.001] d2[0.001] g[18.218]
# >620, d1[0.002] d2[0.176] g[16.098]
# >621, d1[0.088] d2[0.004] g[8.615]
# >622, d1[0.621] d2[0.027] g[8.903]
# >623, d1[0.128] d2[0.021] g[12.673]
# >624, d1[0.002] d2[0.258] g[15.447]
# >625, d1[0.001] d2[0.012] g[13.448]
# >626, d1[0.091] d2[0.033] g[10.038]
# >627, d1[0.001] d2[0.003] g[14.678]
# >628, d1[0.004] d2[0.017] g[12.154]
# >629, d1[0.765] d2[0.194] g[8.367]
# >630, d1[0.011] d2[0.020] g[10.363]
# >631, d1[0.026] d2[0.058] g[11.051]
# >632, d1[0.002] d2[0.196] g[10.875]
# >633, d1[0.001] d2[0.033] g[14.397]
# >634, d1[0.089] d2[0.002] g[12.638]
# >635, d1[0.097] d2[0.377] g[11.443]
# >636, d1[0.238] d2[0.002] g[14.630]
# >637, d1[0.000] d2[0.647] g[16.974]
# >638, d1[0.000] d2[0.011] g[14.231]
# >639, d1[0.965] d2[0.032] g[7.740]
# >640, d1[0.153] d2[0.040] g[12.375]
# >641, d1[0.464] d2[0.012] g[13.600]
# >642, d1[0.003] d2[0.233] g[10.998]
# >643, d1[0.000] d2[0.089] g[14.370]
# >644, d1[0.797] d2[0.298] g[9.038]
# >645, d1[0.000] d2[3.946] g[8.769]
# >646, d1[0.000] d2[0.001] g[22.572]
# >647, d1[0.887] d2[0.324] g[9.783]
# >648, d1[0.000] d2[0.022] g[15.939]
# >649, d1[1.372] d2[0.457] g[8.936]
# >650, d1[0.031] d2[0.014] g[7.305]
# >651, d1[0.069] d2[0.016] g[12.029]
# >652, d1[0.000] d2[0.222] g[14.254]
# >653, d1[0.035] d2[0.036] g[9.893]
# >654, d1[0.010] d2[0.004] g[20.811]
# >655, d1[0.018] d2[0.181] g[9.129]
# >656, d1[0.012] d2[0.008] g[12.969]
# >657, d1[0.515] d2[0.056] g[8.718]
# >658, d1[0.022] d2[0.035] g[10.802]
# >659, d1[0.046] d2[0.011] g[10.099]
# >660, d1[0.003] d2[0.090] g[13.282]
# >661, d1[0.000] d2[0.015] g[14.505]
# >662, d1[0.001] d2[0.049] g[12.159]
# >663, d1[0.021] d2[0.137] g[8.242]
# >664, d1[0.000] d2[0.012] g[24.498]
# >665, d1[0.031] d2[0.001] g[16.644]
# >666, d1[0.260] d2[0.084] g[8.083]
# >667, d1[0.380] d2[0.233] g[9.023]
# >668, d1[0.000] d2[0.044] g[21.087]
# >669, d1[0.002] d2[0.436] g[12.569]
# >670, d1[0.197] d2[0.005] g[12.734]
# >671, d1[0.000] d2[0.002] g[17.456]
# >672, d1[0.011] d2[0.025] g[9.588]
# >673, d1[0.001] d2[0.002] g[15.589]
# >674, d1[0.916] d2[0.290] g[9.796]
# >675, d1[0.020] d2[0.316] g[11.696]
# >676, d1[0.221] d2[0.015] g[10.382]
# >677, d1[0.267] d2[0.057] g[9.878]
# >678, d1[0.001] d2[0.126] g[11.364]
# >679, d1[0.000] d2[0.076] g[14.306]
# >680, d1[0.000] d2[0.000] g[10.470]
# >681, d1[0.013] d2[0.026] g[7.074]
# >682, d1[0.077] d2[0.020] g[6.492]
# >683, d1[0.000] d2[0.026] g[15.113]
# >684, d1[0.000] d2[0.006] g[16.949]
# >685, d1[0.000] d2[0.014] g[13.317]
# >686, d1[0.077] d2[0.030] g[10.698]
# >687, d1[0.168] d2[0.023] g[9.195]
# >688, d1[0.001] d2[0.320] g[12.386]
# >689, d1[0.002] d2[0.005] g[13.431]
# >690, d1[0.000] d2[0.020] g[14.339]
# >691, d1[0.001] d2[0.002] g[12.363]
# >692, d1[0.722] d2[0.192] g[8.996]
# >693, d1[0.002] d2[0.260] g[11.205]
# >694, d1[0.095] d2[0.061] g[9.441]
# >695, d1[0.035] d2[0.004] g[11.665]
# >696, d1[1.029] d2[0.019] g[8.400]
# >697, d1[0.011] d2[0.186] g[10.170]
# >698, d1[0.000] d2[0.064] g[12.185]
# >699, d1[0.016] d2[0.200] g[9.690]
# >700, d1[0.231] d2[0.062] g[11.768]
# >701, d1[0.009] d2[0.148] g[12.625]
# >702, d1[0.009] d2[0.033] g[10.500]
# >703, d1[0.275] d2[0.205] g[8.789]
# >704, d1[0.276] d2[0.001] g[11.300]
# >705, d1[0.000] d2[0.020] g[15.493]
# >706, d1[0.006] d2[0.082] g[9.660]
# >707, d1[0.012] d2[0.017] g[10.689]
# >708, d1[0.001] d2[0.070] g[8.920]
# >709, d1[0.000] d2[0.007] g[19.404]
# >710, d1[0.097] d2[0.051] g[8.793]
# >711, d1[0.006] d2[0.257] g[12.086]
# >712, d1[0.000] d2[0.000] g[13.615]
# >713, d1[0.000] d2[0.003] g[16.029]
# >714, d1[0.282] d2[0.323] g[9.610]
# >715, d1[0.000] d2[0.005] g[15.640]
# >716, d1[0.050] d2[0.001] g[12.864]
# >717, d1[0.298] d2[0.014] g[8.586]
# >718, d1[0.016] d2[0.021] g[11.106]
# >719, d1[0.001] d2[0.156] g[10.321]
# >720, d1[0.001] d2[0.003] g[19.121]
# >721, d1[0.003] d2[0.001] g[13.259]
# >722, d1[0.042] d2[0.041] g[9.235]
# >723, d1[0.025] d2[0.008] g[12.386]
# >724, d1[0.138] d2[0.045] g[11.426]
# >725, d1[0.000] d2[0.000] g[11.771]
# >726, d1[0.002] d2[0.079] g[10.731]
# >727, d1[0.014] d2[0.069] g[11.578]
# >728, d1[0.105] d2[0.325] g[9.732]
# >729, d1[0.002] d2[0.005] g[8.912]
# >730, d1[0.893] d2[0.030] g[7.591]
# >731, d1[0.001] d2[0.038] g[12.103]
# >732, d1[0.022] d2[0.037] g[9.423]
# >733, d1[0.012] d2[0.197] g[10.474]
# >734, d1[0.226] d2[0.098] g[9.611]
# >735, d1[0.011] d2[0.045] g[10.442]
# >736, d1[0.001] d2[0.181] g[7.888]
# >737, d1[0.005] d2[0.030] g[9.805]
# >738, d1[0.089] d2[0.012] g[10.521]
# >739, d1[0.004] d2[0.098] g[9.576]
# >740, d1[0.011] d2[0.205] g[12.361]
# >741, d1[0.577] d2[0.149] g[8.262]
# >742, d1[0.188] d2[0.042] g[8.943]
# >743, d1[0.001] d2[0.000] g[14.139]
# >744, d1[0.062] d2[0.301] g[10.496]
# >745, d1[0.000] d2[0.419] g[16.792]
# >746, d1[1.278] d2[0.036] g[7.663]
# >747, d1[0.103] d2[0.061] g[8.243]
# >748, d1[0.006] d2[0.020] g[11.499]
# >749, d1[0.016] d2[0.168] g[9.907]
# >750, d1[0.011] d2[0.012] g[11.340]
# >751, d1[0.003] d2[0.383] g[13.284]
# >752, d1[0.000] d2[0.001] g[21.165]
# >753, d1[1.898] d2[0.926] g[9.590]
# >754, d1[0.722] d2[0.171] g[7.439]
# >755, d1[0.237] d2[0.010] g[11.298]
# >756, d1[0.245] d2[0.044] g[8.285]
# >757, d1[0.018] d2[0.185] g[13.965]
# >758, d1[0.003] d2[0.057] g[10.645]
# >759, d1[0.012] d2[0.020] g[11.694]
# >760, d1[0.008] d2[0.010] g[13.655]
# >761, d1[0.079] d2[0.043] g[9.420]
# >762, d1[0.346] d2[0.295] g[10.975]
# >763, d1[0.000] d2[0.063] g[11.581]
# >764, d1[0.022] d2[0.041] g[8.952]
# >765, d1[0.000] d2[0.004] g[17.300]
# >766, d1[0.105] d2[0.275] g[9.666]
# >767, d1[0.026] d2[0.013] g[14.176]
# >768, d1[0.618] d2[0.091] g[9.085]
# >769, d1[0.001] d2[0.038] g[13.761]
# >770, d1[0.000] d2[0.816] g[20.341]
# >771, d1[0.000] d2[0.002] g[19.608]
# >772, d1[0.000] d2[0.006] g[19.539]
# >773, d1[0.000] d2[0.002] g[14.901]
# >774, d1[0.000] d2[0.002] g[16.941]
# >775, d1[1.166] d2[0.562] g[9.759]
# >776, d1[1.128] d2[0.225] g[7.618]
# >777, d1[0.041] d2[0.015] g[9.084]
# >778, d1[0.004] d2[0.128] g[11.994]
# >779, d1[0.000] d2[0.876] g[15.610]
# >780, d1[0.783] d2[0.280] g[8.444]
# >781, d1[0.118] d2[0.002] g[15.085]
# >782, d1[0.529] d2[0.555] g[9.775]
# >783, d1[0.000] d2[0.000] g[12.536]
# >784, d1[0.060] d2[0.019] g[13.288]
# >785, d1[0.002] d2[0.006] g[14.584]
# >786, d1[0.157] d2[0.062] g[10.095]
# >787, d1[0.010] d2[0.064] g[9.354]
# >788, d1[0.096] d2[0.014] g[11.931]
# >789, d1[0.000] d2[0.011] g[19.093]
# >790, d1[0.043] d2[0.131] g[9.787]
# >791, d1[0.003] d2[0.038] g[11.932]
# >792, d1[0.000] d2[0.025] g[11.269]
# >793, d1[0.443] d2[0.095] g[8.819]
# >794, d1[0.001] d2[0.799] g[14.262]
# >795, d1[0.000] d2[0.001] g[18.368]
# >796, d1[0.862] d2[0.008] g[10.268]
# >797, d1[0.016] d2[0.007] g[12.854]
# >798, d1[0.040] d2[0.047] g[10.301]
# >799, d1[0.001] d2[0.003] g[8.377]
# >800, d1[0.001] d2[0.015] g[11.667]
# >801, d1[0.028] d2[0.095] g[10.111]
# >802, d1[0.002] d2[0.006] g[7.376]
# >803, d1[0.007] d2[0.086] g[8.186]
# >804, d1[0.152] d2[0.002] g[8.500]
# >805, d1[0.000] d2[0.010] g[16.816]
# >806, d1[0.014] d2[0.042] g[13.177]
# >807, d1[0.081] d2[0.034] g[9.168]
# >808, d1[0.057] d2[0.085] g[9.326]
# >809, d1[0.000] d2[0.204] g[12.520]
# >810, d1[0.000] d2[0.094] g[6.129]
# >811, d1[0.177] d2[0.016] g[10.010]
# >812, d1[0.014] d2[0.001] g[12.829]
# >813, d1[0.119] d2[0.039] g[10.387]
# >814, d1[0.011] d2[0.047] g[11.570]
# >815, d1[0.000] d2[0.043] g[12.992]
# >816, d1[0.298] d2[0.052] g[9.477]
# >817, d1[0.000] d2[0.052] g[17.242]
# >818, d1[0.005] d2[0.762] g[15.661]
# >819, d1[0.063] d2[0.001] g[14.489]
# >820, d1[0.180] d2[0.016] g[9.223]
# >821, d1[0.130] d2[0.015] g[10.652]
# >822, d1[0.131] d2[0.008] g[11.259]
# >823, d1[0.059] d2[0.016] g[11.567]
# >824, d1[0.003] d2[0.229] g[9.954]
# >825, d1[0.004] d2[0.016] g[11.033]
# >826, d1[0.005] d2[0.013] g[8.020]
# >827, d1[0.000] d2[0.001] g[21.791]
# >828, d1[0.000] d2[0.005] g[17.872]
# >829, d1[0.053] d2[0.004] g[13.398]
# >830, d1[0.050] d2[0.004] g[12.639]
# >831, d1[0.028] d2[0.049] g[10.239]
# >832, d1[0.000] d2[0.028] g[13.777]
# >833, d1[0.226] d2[0.160] g[8.671]
# >834, d1[0.020] d2[0.015] g[12.179]
# >835, d1[0.000] d2[0.045] g[12.199]
# >836, d1[0.000] d2[0.620] g[13.872]
# >837, d1[0.255] d2[0.025] g[8.770]
# >838, d1[0.341] d2[0.141] g[8.997]
# >839, d1[0.000] d2[0.006] g[14.537]
# >840, d1[0.008] d2[0.076] g[10.989]
# >841, d1[0.013] d2[0.058] g[11.821]
# >842, d1[0.012] d2[0.083] g[11.143]
# >843, d1[0.001] d2[0.246] g[14.696]
# >844, d1[0.198] d2[0.002] g[12.123]
# >845, d1[0.603] d2[0.021] g[10.383]
# >846, d1[0.008] d2[0.299] g[10.702]
# >847, d1[0.244] d2[0.060] g[9.113]
# >848, d1[0.137] d2[0.136] g[12.783]
# >849, d1[0.008] d2[0.068] g[10.276]
# >850, d1[1.275] d2[0.516] g[11.374]
# >851, d1[0.008] d2[0.158] g[9.882]
# >852, d1[0.060] d2[0.013] g[11.865]
# >853, d1[0.017] d2[0.014] g[9.577]
# >854, d1[0.007] d2[0.003] g[14.674]
# >855, d1[0.025] d2[0.013] g[9.776]
# >856, d1[0.021] d2[0.539] g[15.133]
# >857, d1[0.063] d2[0.010] g[11.925]
# >858, d1[0.016] d2[0.004] g[12.303]
# >859, d1[0.058] d2[0.001] g[15.410]
# >860, d1[0.034] d2[0.054] g[10.475]
# >861, d1[0.056] d2[0.004] g[11.595]
# >862, d1[0.114] d2[0.006] g[17.781]
# >863, d1[0.019] d2[0.012] g[11.004]
# >864, d1[0.043] d2[0.005] g[11.753]
# >865, d1[0.093] d2[0.073] g[8.708]
# >866, d1[0.006] d2[0.064] g[14.662]
# >867, d1[0.002] d2[0.112] g[10.488]
# >868, d1[0.028] d2[0.014] g[11.312]
# >869, d1[0.023] d2[0.001] g[20.352]
# >870, d1[0.000] d2[0.002] g[21.019]
# >871, d1[0.027] d2[0.017] g[10.881]
# >872, d1[0.008] d2[0.028] g[11.456]
# >873, d1[0.061] d2[0.019] g[12.161]
# >874, d1[0.050] d2[0.008] g[10.809]
# >875, d1[0.182] d2[0.114] g[11.005]
# >876, d1[0.000] d2[0.002] g[8.182]
# >877, d1[0.030] d2[0.089] g[10.271]
# >878, d1[0.083] d2[0.141] g[10.019]
# >879, d1[0.058] d2[0.034] g[10.871]
# >880, d1[0.000] d2[0.000] g[12.501]
# >881, d1[0.114] d2[0.018] g[11.613]
# >882, d1[0.048] d2[0.128] g[9.766]
# >883, d1[0.047] d2[0.089] g[9.434]
# >884, d1[0.061] d2[0.007] g[10.238]
# >885, d1[0.000] d2[0.070] g[19.690]
# >886, d1[0.018] d2[0.061] g[10.168]
# >887, d1[0.000] d2[0.045] g[21.140]
# >888, d1[0.002] d2[0.005] g[12.869]
# >889, d1[0.346] d2[0.068] g[14.182]
# >890, d1[0.000] d2[0.009] g[19.979]
# >891, d1[0.009] d2[0.051] g[10.982]
# >892, d1[0.020] d2[0.111] g[10.383]
# >893, d1[0.001] d2[0.004] g[14.751]
# >894, d1[0.578] d2[0.526] g[11.730]
# >895, d1[0.008] d2[0.007] g[15.262]
# >896, d1[0.000] d2[0.002] g[18.232]
# >897, d1[0.025] d2[0.012] g[10.917]
# >898, d1[0.147] d2[0.006] g[12.111]
# >899, d1[0.006] d2[0.040] g[10.360]
# >900, d1[0.000] d2[0.047] g[14.834]
# >901, d1[0.003] d2[0.047] g[12.544]
# >902, d1[0.012] d2[0.019] g[9.362]
# >903, d1[0.001] d2[0.016] g[12.016]
# >904, d1[0.079] d2[0.099] g[9.120]
# >905, d1[0.006] d2[0.011] g[11.656]
# >906, d1[0.002] d2[0.022] g[13.822]
# >907, d1[0.005] d2[0.032] g[11.264]
# >908, d1[0.000] d2[0.008] g[15.787]
# >909, d1[0.000] d2[0.019] g[14.593]
# >910, d1[0.076] d2[0.018] g[11.463]
# >911, d1[0.327] d2[0.510] g[12.765]
# >912, d1[0.025] d2[0.005] g[12.083]
# >913, d1[0.707] d2[0.090] g[8.496]
# >914, d1[0.000] d2[0.169] g[15.039]
# >915, d1[0.060] d2[0.033] g[11.850]
# >916, d1[0.001] d2[0.085] g[9.933]
# >917, d1[0.000] d2[0.004] g[18.731]
# >918, d1[0.091] d2[0.031] g[8.657]
# >919, d1[0.006] d2[0.535] g[12.325]
# >920, d1[0.000] d2[0.000] g[18.767]
# >921, d1[0.001] d2[0.000] g[15.723]
# >922, d1[0.001] d2[0.001] g[18.414]
# >923, d1[0.000] d2[0.001] g[17.952]
# >924, d1[0.184] d2[0.010] g[11.902]
# >925, d1[0.094] d2[0.044] g[8.555]
# >926, d1[0.041] d2[0.009] g[12.844]
# >927, d1[0.000] d2[0.008] g[14.574]
# >928, d1[0.026] d2[0.027] g[9.840]
# >929, d1[0.008] d2[0.010] g[12.210]
# >930, d1[0.839] d2[0.121] g[6.550]
# >931, d1[0.001] d2[0.432] g[11.383]
# >932, d1[0.002] d2[0.086] g[12.698]
# >933, d1[0.000] d2[0.003] g[17.041]
# >934, d1[0.139] d2[0.054] g[8.051]
# >935, d1[0.025] d2[0.022] g[10.584]
# >936, d1[0.145] d2[0.012] g[9.435]
# >937, d1[0.019] d2[0.079] g[10.720]
# >938, d1[0.001] d2[0.022] g[14.033]
# >939, d1[0.000] d2[0.006] g[15.311]
# >940, d1[0.003] d2[0.071] g[11.170]
# >941, d1[0.039] d2[0.019] g[10.421]
# >942, d1[0.017] d2[0.118] g[10.329]
# >943, d1[0.093] d2[0.049] g[9.129]
# >944, d1[0.117] d2[0.023] g[11.181]
# >945, d1[0.054] d2[0.167] g[10.040]
# >946, d1[0.019] d2[0.045] g[10.935]
# >947, d1[0.000] d2[0.008] g[18.810]
# >948, d1[0.228] d2[0.018] g[10.133]
# >949, d1[0.007] d2[0.019] g[12.079]
# >950, d1[0.039] d2[0.018] g[12.214]
# >951, d1[0.013] d2[0.068] g[9.300]
# >952, d1[0.001] d2[0.003] g[10.934]
# >953, d1[0.001] d2[0.006] g[10.473]
# >954, d1[0.017] d2[0.067] g[7.019]
# >955, d1[0.008] d2[0.002] g[13.974]
# >956, d1[0.366] d2[0.123] g[10.515]
# >957, d1[0.001] d2[0.140] g[12.374]
# >958, d1[0.039] d2[0.016] g[9.908]
# >959, d1[0.001] d2[0.075] g[11.111]
# >960, d1[0.005] d2[0.000] g[14.025]
# >961, d1[0.042] d2[0.064] g[9.848]
# >962, d1[0.084] d2[0.016] g[11.314]
# >963, d1[0.000] d2[0.022] g[14.360]
# >964, d1[0.000] d2[0.020] g[21.430]
# >965, d1[0.078] d2[0.047] g[9.778]
# >966, d1[0.073] d2[0.050] g[9.232]
# >967, d1[0.000] d2[0.143] g[15.754]
# >968, d1[0.002] d2[0.020] g[13.506]
# >969, d1[0.138] d2[0.020] g[9.584]
# >970, d1[0.000] d2[0.006] g[16.661]
# >971, d1[0.000] d2[0.000] g[12.022]
# >972, d1[0.042] d2[0.011] g[10.836]
# >973, d1[0.186] d2[0.289] g[8.724]
# >974, d1[0.009] d2[0.064] g[8.800]
# >975, d1[0.009] d2[0.000] g[10.666]
# >976, d1[0.017] d2[0.051] g[11.403]
# >977, d1[0.074] d2[0.126] g[11.155]
# >978, d1[0.152] d2[0.000] g[16.634]
# >979, d1[0.002] d2[0.218] g[13.081]
# >980, d1[0.251] d2[0.028] g[8.963]
# >981, d1[0.026] d2[0.003] g[13.558]
# >982, d1[0.008] d2[0.013] g[9.074]
# >983, d1[0.044] d2[0.083] g[8.953]
# >984, d1[0.014] d2[0.009] g[10.233]
# >985, d1[0.016] d2[0.003] g[11.005]
# >986, d1[0.044] d2[0.032] g[9.602]
# >987, d1[0.006] d2[0.000] g[16.078]
# >988, d1[0.000] d2[0.008] g[15.076]
# >989, d1[0.005] d2[0.001] g[19.963]
# >990, d1[0.014] d2[0.006] g[13.268]
# >991, d1[0.000] d2[0.031] g[12.652]
# >992, d1[0.000] d2[0.026] g[16.395]
# >993, d1[0.050] d2[0.029] g[9.639]
# >994, d1[0.012] d2[0.158] g[10.375]
# >995, d1[0.069] d2[0.021] g[7.980]
# >996, d1[0.000] d2[0.001] g[20.077]
# >997, d1[0.002] d2[0.002] g[14.727]
# >998, d1[0.069] d2[0.013] g[10.572]
# >999, d1[0.000] d2[0.039] g[11.811]
# >1000, d1[0.046] d2[0.004] g[12.851]
# >1001, d1[0.017] d2[0.005] g[15.482]
# >1002, d1[0.002] d2[0.004] g[15.459]
# >1003, d1[0.012] d2[0.022] g[9.840]
# >1004, d1[0.001] d2[0.023] g[12.018]
# >1005, d1[0.012] d2[0.008] g[11.657]
# >1006, d1[0.018] d2[0.215] g[11.413]
# >1007, d1[0.066] d2[0.019] g[8.787]
# >1008, d1[0.068] d2[0.082] g[7.538]
# >1009, d1[0.007] d2[0.006] g[12.625]
# >1010, d1[0.003] d2[0.003] g[14.896]
# >1011, d1[0.028] d2[0.001] g[10.431]
# >1012, d1[0.022] d2[0.020] g[9.774]
# >1013, d1[0.000] d2[0.003] g[16.036]
# >1014, d1[0.032] d2[0.002] g[12.766]
# >1015, d1[0.077] d2[0.014] g[10.608]
# >1016, d1[0.236] d2[0.051] g[10.058]
# >1017, d1[0.010] d2[0.285] g[13.547]
# >1018, d1[0.000] d2[0.028] g[17.398]
# >1019, d1[0.000] d2[0.001] g[18.529]
# >1020, d1[0.161] d2[0.030] g[10.134]
# >1021, d1[0.000] d2[0.001] g[15.761]
# >1022, d1[0.000] d2[0.006] g[14.410]
# >1023, d1[0.113] d2[0.012] g[10.089]
# >1024, d1[0.000] d2[0.001] g[10.782]
# >1025, d1[0.020] d2[0.117] g[11.393]
# >1026, d1[0.013] d2[0.003] g[10.761]
# >1027, d1[0.001] d2[0.141] g[11.789]
# >1028, d1[0.000] d2[0.004] g[16.378]
# >1029, d1[0.158] d2[0.013] g[10.405]
# >1030, d1[0.093] d2[0.008] g[9.398]
# >1031, d1[0.000] d2[0.011] g[14.455]
# >1032, d1[0.016] d2[0.095] g[8.264]
# >1033, d1[0.457] d2[0.487] g[15.188]
# >1034, d1[0.001] d2[0.002] g[15.005]
# >1035, d1[0.015] d2[0.001] g[15.202]
# >1036, d1[0.379] d2[0.201] g[12.276]
# >1037, d1[0.004] d2[0.046] g[10.960]
# >1038, d1[0.030] d2[0.060] g[11.156]
# >1039, d1[0.066] d2[0.016] g[12.001]
# >1040, d1[0.036] d2[0.041] g[10.422]
# >1041, d1[0.010] d2[0.121] g[12.231]
# >1042, d1[0.005] d2[0.015] g[6.475]
# >1043, d1[0.791] d2[0.549] g[12.874]
# >1044, d1[0.000] d2[0.001] g[16.219]
# >1045, d1[0.370] d2[0.087] g[9.216]
# >1046, d1[0.033] d2[0.002] g[11.555]
# >1047, d1[0.031] d2[0.002] g[8.699]
# >1048, d1[0.002] d2[0.353] g[13.857]
# >1049, d1[0.011] d2[0.041] g[11.301]
# >1050, d1[0.000] d2[0.002] g[17.175]
# >1051, d1[1.020] d2[0.277] g[12.250]
# >1052, d1[0.000] d2[1.221] g[17.294]
# >1053, d1[0.190] d2[0.004] g[11.729]
# >1054, d1[0.056] d2[0.002] g[14.421]
# >1055, d1[0.394] d2[0.308] g[11.041]
# >1056, d1[1.177] d2[0.030] g[8.670]
# >1057, d1[0.007] d2[0.150] g[13.717]
# >1058, d1[0.011] d2[0.028] g[13.051]
# >1059, d1[0.073] d2[0.113] g[10.042]
# >1060, d1[0.027] d2[0.042] g[11.666]
# >1061, d1[0.108] d2[0.152] g[12.419]
# >1062, d1[0.010] d2[0.089] g[9.522]
# >1063, d1[0.078] d2[0.014] g[11.988]
# >1064, d1[0.000] d2[0.159] g[7.795]
# >1065, d1[0.000] d2[0.055] g[13.597]
# >1066, d1[0.300] d2[0.210] g[10.688]
# >1067, d1[0.200] d2[0.018] g[13.179]
# >1068, d1[0.012] d2[0.094] g[11.533]
# >1069, d1[0.000] d2[0.095] g[14.522]
# >1070, d1[0.035] d2[0.053] g[10.718]
# >1071, d1[0.017] d2[0.014] g[10.301]
# >1072, d1[0.154] d2[0.048] g[9.133]
# >1073, d1[0.083] d2[0.012] g[10.699]
# >1074, d1[0.012] d2[0.116] g[10.602]
# >1075, d1[0.011] d2[0.006] g[8.802]
# >1076, d1[0.001] d2[0.361] g[13.108]
# >1077, d1[0.157] d2[0.014] g[11.953]
# >1078, d1[0.152] d2[0.184] g[10.719]
# >1079, d1[0.341] d2[0.017] g[9.521]
# >1080, d1[0.046] d2[0.003] g[12.392]
# >1081, d1[0.001] d2[0.036] g[12.020]
# >1082, d1[0.000] d2[0.120] g[24.143]
# >1083, d1[0.000] d2[2.677] g[19.334]
# >1084, d1[1.657] d2[0.000] g[11.923]
# >1085, d1[0.084] d2[0.010] g[9.100]
# >1086, d1[1.488] d2[0.167] g[14.193]
# >1087, d1[0.005] d2[0.014] g[9.715]
# >1088, d1[0.000] d2[0.917] g[18.156]
# >1089, d1[0.011] d2[0.002] g[11.525]
# >1090, d1[1.446] d2[0.029] g[7.577]
# >1091, d1[0.236] d2[0.272] g[11.025]
# >1092, d1[0.006] d2[0.675] g[13.297]
# >1093, d1[0.000] d2[0.006] g[16.273]
# >1094, d1[0.304] d2[0.046] g[9.138]
# >1095, d1[0.001] d2[0.011] g[15.634]
# >1096, d1[0.180] d2[0.070] g[10.395]

# %%
d_model.save("d_model.h5")
g_model.save("g_model.h5") 
gan_model.save("gan_model.h5")

# %%
# !curl --upload-file ./d_model.h5 https://transfer.sh/d_model.h5
# Out:
# https://transfer.sh/3X62I/d_model.h5

# %%
# !curl --upload-file ./g_model.h5 https://transfer.sh/g_model.h5
# Out:
# https://transfer.sh/keju6/g_model.h5

# %%
# !curl --upload-file ./gan_model.h5 https://transfer.sh/gan_model.h5
# Out:
# https://transfer.sh/m3Kss/gan_model.h5

# %%
# !wget https://transfer.sh/3X62I/d_model.h5
# Out:
# --2019-08-12 17:37:18--  https://transfer.sh/3X62I/d_model.h5
# Resolving transfer.sh (transfer.sh)... 144.76.136.153
# Connecting to transfer.sh (transfer.sh)|144.76.136.153|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 83680784 (80M) [application/octet-stream]
# Saving to: ‘d_model.h5’
#
# d_model.h5          100%[===================>]  79.80M  10.4MB/s    in 8.6s
#
# 2019-08-12 17:37:40 (9.23 MB/s) - ‘d_model.h5’ saved [83680784/83680784]

# %%
# !wget https://transfer.sh/keju6/g_model.h5
# Out:
# --2019-08-12 17:37:42--  https://transfer.sh/keju6/g_model.h5
# Resolving transfer.sh (transfer.sh)... 144.76.136.153
# Connecting to transfer.sh (transfer.sh)|144.76.136.153|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 217866512 (208M) [application/octet-stream]
# Saving to: ‘g_model.h5’
#
# g_model.h5          100%[===================>] 207.77M  11.6MB/s    in 20s
#
# 2019-08-12 17:38:09 (10.6 MB/s) - ‘g_model.h5’ saved [217866512/217866512]

# %%
# !wget https://transfer.sh/m3Kss/gan_model.h5
# Out:
# --2019-08-11 07:26:51--  https://transfer.sh/m3Kss/gan_model.h5
# Resolving transfer.sh (transfer.sh)... 144.76.136.153
# Connecting to transfer.sh (transfer.sh)|144.76.136.153|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 681146048 (650M) [application/octet-stream]
# Saving to: ‘gan_model.h5’
#
# gan_model.h5        100%[===================>] 649.59M  13.4MB/s    in 35s
#
# 2019-08-11 07:27:27 (18.6 MB/s) - ‘gan_model.h5’ saved [681146048/681146048]

# %%
###################
##### TEST ########
###################

# %%
# example of loading a pix2pix model and using it for image to image translation
from keras.models import load_model
from numpy import load
from numpy import vstack
from matplotlib import pyplot
from numpy.random import randint

# load and prepare training images
def load_real_samples(filename):
	# load compressed arrays
	data = load(filename)
	# unpack arrays
	X1, X2 = data['arr_0'], data['arr_1']
	# scale from [0,255] to [-1,1]
	X1 = (X1 - 127.5) / 127.5
	X2 = (X2 - 127.5) / 127.5
	return [X1, X2]

# plot source, generated and target images
def plot_images(src_img, gen_img, tar_img):
	images = vstack((src_img, gen_img, tar_img))
	# scale from [-1,1] to [0,1]
	images = (images + 1) / 2.0
	titles = ['Source', 'Generated', 'Expected']
	# plot images row by row
	for i in range(len(images)):
		# define subplot
		pyplot.subplot(1, 3, 1 + i)
		# turn off axis
		pyplot.axis('off')
		# plot raw pixel data
		pyplot.imshow(images[i])
		# show title
		pyplot.title(titles[i])
	pyplot.show()

# load dataset
[X1, X2] = load_real_samples('maps_256.npz')
print('Loaded', X1.shape, X2.shape)
# load model
model = load_model('g_model.h5')
# select random example
ix = randint(0, len(X1), 1)
print(ix)
src_image, tar_image = X1[ix], X2[ix]
# generate image from source
gen_image = model.predict(src_image)
# plot all three images
plot_images(src_image, gen_image, tar_image)
print(type(src_image), gen_image.shape, tar_image.shape)
# Out:
# Loaded (1096, 256, 256, 3) (1096, 256, 256, 3)
# /usr/local/lib/python3.6/dist-packages/keras/engine/saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '
# [42]
# <class 'numpy.ndarray'> (1, 256, 256, 3) (1, 256, 256, 3)

# %%
src_image.shape
# Out:
# (1, 256, 256, 3)

# %%
# load, split and scale the maps dataset ready for training
import os
from keras.preprocessing.image import img_to_array
from keras.preprocessing.image import load_img
from matplotlib import pyplot as plt
import numpy as np
from numpy import vstack
import time


model = load_model('g_model.h5')
# Out:
# /usr/local/lib/python3.6/dist-packages/keras/engine/saving.py:292: UserWarning: No training configuration found in save file: the model was *not* compiled. Compile it manually.
#   warnings.warn('No training configuration found in save file: '

# %%
filename="./maps/val/551.jpg"
size=(256,512)
pixels = load_img(filename, target_size=size)

# convert to numpy array
pixels = img_to_array(pixels)
# split into satellite and map
sat_img, map_img = pixels[:, :256], pixels[:, 256:]
sat_img = (sat_img - 127.5) / 127.5
map_img = (map_img - 127.5) / 127.5

input_image=[]
input_image.append(sat_img)
input_image=np.array(input_image)

print(input_image.shape)

t1=time.time()
gen_image=model.predict(input_image)
t2=time.time()
# Out:
# (1, 256, 256, 3)

# %%
# plot source, generated and target images
def show_images(src_img, gen_img):
	images = vstack((src_img, gen_img))
	# scale from [-1,1] to [0,1]
	images = (images + 1) / 2.0
	titles = ['Source', 'Generated']
	# plot images row by row
	for i in range(len(images)):
		# define subplot
		pyplot.subplot(1, 2, 1 + i)
		# turn off axis
		pyplot.axis('off')
		# plot raw pixel data
		pyplot.imshow(images[i])
		# show title
		pyplot.title(titles[i])
	pyplot.show()

show_images(input_image,gen_image)

# %%
    show_images(input_image,gen_image)

# %%
show_images(input_image,gen_image)
